# %%
#  Last amended: 15th August, 2019
#  Myfolder: /home/ashok/Documents/spark
# Ref:
# Tutorials:
#      https://changhsinlee.com/pyspark-dataframe-basics/
#      https://www.analyticsvidhya.com/blog/2016/10/spark-dataframe-and-operations/
#      https://dzone.com/articles/pyspark-dataframe-tutorial-introduction-to-datafra
# Documentation:
#      http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark-sql-module
#      http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#module-pyspark.sql.functions
# Cheat Sheet
#      https://s3.amazonaws.com/assets.datacamp.com/blog_assets/PySpark_SQL_Cheat_Sheet_Python.pdf

#  Objectives:
#           Dataframe operations in spark cluster
#           Dealing with categorical columns
#               i) StrinIndexing them
#              ii) OneHotEncoding
#             iii) PipeLining for multiple columns

# %% [markdown]
# A. Initial operations:
# 1.0 Start hadoop in a terminal:
#
#             ./allstart.sh

# %%
# 1.1 Transfer two data files, airports.csv and  weather.csv,
#         from local file system to hadoop. 
#         COPY AND PASTE in terminal all the four commands below.
"""

cd ~
hdfs dfs -put /cdata/nycflights13/airports.csv hdfs://localhost:9000/user/ashok/data_files/nycflights
hdfs dfs -put /cdata/nycflights13/weather.csv hdfs://localhost:9000/user/ashok/data_files/nycflights
hdfs dfs -ls -h hdfs://localhost:9000/user/ashok/data_files/nycflights

"""

# %%
# 1.2 Start pyspark in terminal. Its starting creates a context 'sc' and session 'spark'
#     Jupyter notebook will also start then. pyspark is using juptyter notebook as interface
#     COPY AND PASTE FOLLOWING TWO COMMANDS
"""

cd /home/ashok/Documents/spark/1.basics/
pyspark

"""

# %%
# Display multiple outputs from a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Increase cell width to display wide columnar output
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# 1.3 To check if spark context is ,sc, and spark session is, spark: 
#        try the following two commands. Also right-click on Spark_UI hyperlink
#        to open another site.
#      Spark 'driver' process manifests itself through 'spark' session object

sc
spark
# Out:
# <SparkContext master=local[*] appName=PySparkShell>
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://master:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Spark DataFrame creation

# %%
# 1.4 Using 'spark' session, create a range of numbers 

myRange = spark.range(10000)
type(myRange)
myRange.show(3)
# Out:
# pyspark.sql.dataframe.DataFrame
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# +---+
# only showing top 3 rows

# %%
#  Use createDataFrame() . This is preferred method.
#  1.4.1 From a list of tuples:
#  1.4.1 No schema. Column names are given on its own
df = spark.createDataFrame([(11,12,31), (4,5,6)])
df.show()
# 1.4.2 Specify schema
df = spark.createDataFrame([(1,2,3), (4,5,6)], schema = ['age', 'income','ht']).show()
# Out:
# +---+---+---+
# | _1| _2| _3|
# +---+---+---+
# | 11| 12| 31|
# |  4|  5|  6|
# +---+---+---+
#
# +---+------+---+
# |age|income| ht|
# +---+------+---+
# |  1|     2|  3|
# |  4|     5|  6|
# +---+------+---+

# %%
# 1.5.1 From a list of dictionaries:

df = spark.createDataFrame([ {'name':['Alice', 'kishan'], 'age' : [22,44]}]).show()

df = spark.createDataFrame([ {'name':['Alice'], 'age' : [22]},
                             {'name':['kishan'], 'age' : [44]}]).show()

df = spark.createDataFrame([ {'name':'Alice', 'age' : 22},
                             {'name':'kishan' , 'age' : 44}]).show()
# Out:
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"
# +--------+---------------+
# |     age|           name|
# +--------+---------------+
# |[22, 44]|[Alice, kishan]|
# +--------+---------------+
#
# +----+--------+
# | age|    name|
# +----+--------+
# |[22]| [Alice]|
# |[44]|[kishan]|
# +----+--------+
#
# +---+------+
# |age|  name|
# +---+------+
# | 22| Alice|
# | 44|kishan|
# +---+------+

# %%
# 1.5.3 Using Pandas

import pandas as pd
import numpy as np
pdf = pd.DataFrame({'age' : np.random.randint(20,50, 10000),    
                    'married' : np.random.randint(0,2,10000)
                    }
                  )
pdf.head(3)

#  1.5.4 Transform it to spark dataframe
#        Note that unlike pandas, there is no concept
#        of index here.
big = spark.createDataFrame(pdf)
big.show(3)
big.count()   # How many rows
# Out:
#    age  married
# 0   29        0
# 1   43        0
# 2   34        0
# +---+-------+
# |age|married|
# +---+-------+
# | 29|      0|
# | 43|      0|
# | 34|      0|
# +---+-------+
# only showing top 3 rows
# 10000

# %%
# 1.5.5 Using 'Row' object of dataset
from pyspark.sql import Row

# Create an RDD
df = sc.parallelize([ 
                     Row(name='Alice', age=5, height=80), 
                     Row(name='Alice', age=5, height=80), 
                     Row(name='Alice', age=10, height=80),
                     Row(name=None, age=None, height=None)
                     ]
                    )

type(df)      #
df
# Out:
# pyspark.rdd.RDD
# ParallelCollectionRDD[80] at parallelize at PythonRDD.scala:195

# %%
# 1.5.6 Transform to dataframe and process
df1 = df.toDF()
type(df1)
df1.dropDuplicates().show()
df1.dropna().show()
df1.dtypes
# Out:
# pyspark.sql.dataframe.DataFrame
# +----+------+-----+
# | age|height| name|
# +----+------+-----+
# |   5|    80|Alice|
# |null|  null| null|
# |  10|    80|Alice|
# +----+------+-----+
#
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  5|    80|Alice|
# |  5|    80|Alice|
# | 10|    80|Alice|
# +---+------+-----+
# [('age', 'bigint'), ('height', 'bigint'), ('name', 'string')]

# %%
# 1.5.7  Take a stratified sample from DataFrame:
#              80% of 0s and 10% of 1s
#              We have to decide how stratification will be done.

sample = big.sampleBy("married", fractions = {0 : 0.8, 1 : 0.2 })
type(sample)
# 1.5.8
big.count()
sample.count()
# 1.5.9
sample.groupby('married').count().show()   # Same as value_counts() in pandas
big.groupby('married').count().show()
# Out:
# pyspark.sql.dataframe.DataFrame
# 10000
# 4946
# +-------+-----+
# |married|count|
# +-------+-----+
# |      0| 3924|
# |      1| 1022|
# +-------+-----+
#
# +-------+-----+
# |married|count|
# +-------+-----+
# |      0| 4907|
# |      1| 5093|
# +-------+-----+

# %%
###### B. Read Dataset from hadoop
# 2.0 Read 'airports.csv file into spark from hadoop

# Where is my file? Path:
URL_of_file= "hdfs://localhost:9000/user/ashok/data_files/nycflights/"

# 2.0.1 Takes time. We use 'spark' session object to read file:
airports_df = spark.read.csv(path = URL_of_file + "airports.csv",
                             inferSchema = True,
                             header = True
                            )

# %%
# 2.1 Show top-5 rows
# 2.1.1
airports_df.head(3)         #    List of four 'Row' instances. 
airports_df.take(3)         #    Result same as above but prefer take() to head()
airports_df.collect()       #   collect() takes no number and returns all rows
# Out:
# [Row(faa='04G', name='Lansdowne Airport', lat=41.1304722, lon=-80.6195833, alt=1044, tz=-5, dst='A'),
#  Row(faa='06A', name='Moton Field Municipal Airport', lat=32.4605722, lon=-85.6800278, alt=264, tz=-5, dst='A'),
#  Row(faa='06C', name='Schaumburg Regional', lat=41.9893408, lon=-88.1012428, alt=801, tz=-6, dst='A')]
# [Row(faa='04G', name='Lansdowne Airport', lat=41.1304722, lon=-80.6195833, alt=1044, tz=-5, dst='A'),
#  Row(faa='06A', name='Moton Field Municipal Airport', lat=32.4605722, lon=-85.6800278, alt=264, tz=-5, dst='A'),
#  Row(faa='06C', name='Schaumburg Regional', lat=41.9893408, lon=-88.1012428, alt=801, tz=-6, dst='A')]
# [Row(faa='04G', name='Lansdowne Airport', lat=41.1304722, lon=-80.6195833, alt=1044, tz=-5, dst='A'),
#  Row(faa='06A', name='Moton Field Municipal Airport', lat=32.4605722, lon=-85.6800278, alt=264, tz=-5, dst='A'),
#  Row(faa='06C', name='Schaumburg Regional', lat=41.9893408, lon=-88.1012428, alt=801, tz=-6, dst='A'),
#  Row(faa='06N', name='Randall Airport', lat=41.431912, lon=-74.3915611, alt=523, tz=-5, dst='A'),
#  Row(faa='09J', name='Jekyll Island Airport', lat=31.0744722, lon=-81.4277778, alt=11, tz=-4, dst='A'),
#  Row(faa='0A9', name='Elizabethton Municipal Airport', lat=36.3712222, lon=-82.1734167, alt=1593, tz=-4, dst='A'),
#  Row(faa='0G6', name='Williams County Airport', lat=41.4673056, lon=-84.5067778, alt=730, tz=-5, dst='A'),
#  Row(faa='0G7', name='Finger Lakes Regional Airport', lat=42.8835647, lon=-76.7812318, alt=492, tz=-5, dst='A'),
#  Row(faa='0P2', name='Shoestring Aviation Airfield', lat=39.7948244, lon=-76.6471914, alt=1000, tz=-5, dst='U'),
#  Row(faa='0S9', name='Jefferson County Intl', lat=48.0538086, lon=-122.8106436, alt=108, tz=-8, dst='A'),
#  Row(faa='0W3', name='Harford County Airport', lat=39.5668378, lon=-76.2024028, alt=409, tz=-5, dst='A'),
#  Row(faa='10C', name='Galt Field Airport', lat=42.4028889, lon=-88.3751111, alt=875, tz=-6, dst='U'),
#  Row(faa='17G', name='Port Bucyrus-Crawford County Airport', lat=40.7815556, lon=-82.9748056, alt=1003, tz=-5, dst='A'),
#  Row(faa='19A', name='Jackson County Airport', lat=34.1758638, lon=-83.5615972, alt=951, tz=-4, dst='U'),
#  Row(faa='1A3', name='Martin Campbell Field Airport', lat=35.0158056, lon=-84.3468333, alt=1789, tz=-4, dst='A'),
#  Row(faa='1B9', name='Mansfield Municipal', lat=42.0001331, lon=-71.1967714, alt=122, tz=-5, dst='A'),
#  Row(faa='1C9', name='Frazier Lake Airpark', lat=54.0133333333333, lon=-124.768333333333, alt=152, tz=-8, dst='A'),
#  Row(faa='1CS', name='Clow International Airport', lat=41.6959744, lon=-88.1292306, alt=670, tz=-6, dst='U'),
#  Row(faa='1G3', name='Kent State Airport', lat=41.1513889, lon=-81.4151111, alt=1134, tz=-4, dst='A'),
#  Row(faa='1OH', name='Fortman Airport', lat=40.5553253, lon=-84.3866186, alt=885, tz=-5, dst='U'),
#  Row(faa='1RL', name='Point Roberts Airpark', lat=48.9797222, lon=-123.0788889, alt=10, tz=-7, dst='A'),
#  Row(faa='24C', name='Lowell City Airport', lat=42.95392, lon=-85.3439058, alt=681, tz=-5, dst='A'),
#  Row(faa='24J', name='Suwannee County Airport', lat=30.300125, lon=-83.0246944, alt=104, tz=-5, dst='A'),
#  Row(faa='25D', name='Forest Lake Airport', lat=45.2477456, lon=-92.9943853, alt=925, tz=-5, dst='A'),
#  Row(faa='29D', name='Grove City Airport', lat=41.1460278, lon=-80.16775, alt=1371, tz=-5, dst='A'),
#  Row(faa='2A0', name='Mark Anton Airport', lat=35.48625, lon=-84.9310833, alt=718, tz=-4, dst='A'),
#  Row(faa='2G2', name='Jefferson County Airpark', lat=40.3602179, lon=-80.7008742, alt=1196, tz=-4, dst='A'),
#  Row(faa='2G9', name='Somerset County Airport', lat=40.0388708, lon=-79.0149951, alt=2275, tz=-5, dst='A'),
#  Row(faa='2J9', name='Quincy Municipal Airport', lat=30.5978708, lon=-84.557425, alt=225, tz=-5, dst='A'),
#  Row(faa='369', name='Atmautluak Airport', lat=60.866667, lon=-162.273056, alt=18, tz=-10, dst='A'),
#  Row(faa='36U', name='Heber City Municipal Airport', lat=40.4818056, lon=-111.4288056, alt=5637, tz=-6, dst='A'),
#  Row(faa='38W', name='Lynden Airport', lat=48.9558961, lon=-122.4581183, alt=106, tz=-8, dst='A'),
#  Row(faa='3D2', name='Ephraim-Gibraltar Airport', lat=45.1354167, lon=-87.1879444, alt=773, tz=-5, dst='A'),
#  Row(faa='3G3', name='Wadsworth Municipal', lat=41.0031572, lon=-81.7564401, alt=974, tz=-5, dst='A'),
#  Row(faa='3G4', name='Ashland County Airport', lat=40.9029722, lon=-82.2556389, alt=1206, tz=-5, dst='A'),
#  Row(faa='3J1', name='Ridgeland Airport', lat=32.4934167, lon=-80.99175, alt=79, tz=-5, dst='A'),
#  Row(faa='3W2', name='Put-in-Bay Airport', lat=41.3521, lon=-82.497, alt=595, tz=-6, dst='A'),
#  Row(faa='40J', name='Perry-Foley Airport', lat=30.0692778, lon=-83.5805833, alt=44, tz=-5, dst='A'),
#  Row(faa='41N', name='Braceville Airport', lat=41.2111675, lon=-80.9692572, alt=900, tz=-5, dst='A'),
#  Row(faa='47A', name='Cherokee County Airport', lat=34.3122175, lon=-84.4221556, alt=1219, tz=-4, dst='A'),
#  Row(faa='49A', name='Gilmer County Airport', lat=34.6282222, lon=-84.5265833, alt=1486, tz=-4, dst='A'),
#  Row(faa='49X', name='Chemehuevi Valley', lat=34.528889, lon=-114.431971, alt=638, tz=-8, dst='A'),
#  Row(faa='4A4', name='Polk County Airport - Cornelius Moore Field', lat=34.0186944, lon=-85.1464722, alt=974, tz=-4, dst='A'),
#  Row(faa='4A7', name='Clayton County Tara Field', lat=33.389099, lon=-84.332397, alt=874, tz=-5, dst='A'),
#  Row(faa='4A9', name='Isbell Field Airport', lat=34.4736944, lon=-85.7213889, alt=877, tz=-5, dst='A'),
#  Row(faa='4B8', name='Robertson Field', lat=41.6893333, lon=-72.8646944, alt=202, tz=-5, dst='A'),
#  Row(faa='4G0', name='Pittsburgh-Monroeville Airport', lat=40.4526389, lon=-79.7749167, alt=1187, tz=-5, dst='A'),
#  Row(faa='4G2', name='Hamburg Inc Airport', lat=42.7008925, lon=-78.9147569, alt=751, tz=-5, dst='A'),
#  Row(faa='4G4', name='Youngstown Elser Metro Airport', lat=40.9617953, lon=-80.6773264, alt=1070, tz=-5, dst='A'),
#  Row(faa='4I7', name='Putnam County Airport', lat=39.6335556, lon=-86.8138056, alt=842, tz=-5, dst='U'),
#  Row(faa='4U9', name='Dell Flight Strip', lat=44.7357483, lon=-112.7200133, alt=6007, tz=-7, dst='A'),
#  Row(faa='52A', name='Madison GA Municipal Airport', lat=33.612125, lon=-83.4604444, alt=694, tz=-5, dst='A'),
#  Row(faa='54J', name='DeFuniak Springs Airport', lat=30.7311111, lon=-86.1537778, alt=289, tz=-5, dst='A'),
#  Row(faa='55J', name='Fernandina Beach Municipal Airport', lat=30.6118333, lon=-81.4611944, alt=16, tz=-4, dst='A'),
#  Row(faa='57C', name='East Troy Municipal Airport', lat=42.7971667, lon=-88.3726111, alt=860, tz=-6, dst='A'),
#  Row(faa='60J', name='Ocean Isle Beach Airport', lat=33.9085056, lon=-78.4366722, alt=32, tz=-5, dst='U'),
#  Row(faa='6A2', name='Griffin-Spalding County Airport', lat=33.2269722, lon=-84.2749444, alt=958, tz=-5, dst='A'),
#  Row(faa='6K8', name='Tok Junction Airport', lat=63.329444, lon=-142.953611, alt=1639, tz=-9, dst='A'),
#  Row(faa='6S0', name='Big Timber Airport', lat=45.8063889, lon=-109.9811111, alt=4492, tz=-7, dst='A'),
#  Row(faa='6S2', name='Florence', lat=43.9828168, lon=-124.1113687, alt=51, tz=-7, dst='A'),
#  Row(faa='6Y8', name='Welke Airport', lat=45.721111, lon=-85.520278, alt=664, tz=-5, dst='A'),
#  Row(faa='70J', name='Cairo-Grady County Airport', lat=30.8879767, lon=-84.1547353, alt=265, tz=-5, dst='A'),
#  Row(faa='70N', name='Spring Hill Airport', lat=41.3473569, lon=-75.4158972, alt=1729, tz=-5, dst='A'),
#  Row(faa='7A4', name='Foster Field', lat=42.4664444, lon=-90.1693889, alt=990, tz=-6, dst='A'),
#  Row(faa='7D9', name='Germack Airport', lat=41.7778322, lon=-80.9039797, alt=820, tz=-5, dst='A'),
#  Row(faa='7N7', name='Spitfire Aerodrome', lat=39.7355633, lon=-75.3977211, alt=40, tz=-5, dst='A'),
#  Row(faa='8M8', name='Garland Airport', lat=44.8065278, lon=-84.2761944, alt=1218, tz=-5, dst='A'),
#  Row(faa='93C', name='Richland Airport', lat=43.2833575, lon=-90.2982819, alt=742, tz=-6, dst='A'),
#  Row(faa='99N', name='Bamberg County Airport', lat=33.3045278, lon=-81.1084167, alt=231, tz=-5, dst='A'),
#  Row(faa='9A1', name='Covington Municipal Airport', lat=33.6323083, lon=-83.8474472, alt=809, tz=-4, dst='A'),
#  Row(faa='9A5', name='Barwick Lafayette Airport', lat=34.6884792, lon=-85.2903319, alt=777, tz=-4, dst='A'),
#  Row(faa='A39', name='Phoenix Regional Airport', lat=32.99169921875, lon=-111.920997619629, alt=1300, tz=-7, dst='A'),
#  Row(faa='AAF', name='Apalachicola Regional Airport', lat=29.7276066, lon=-85.0274416, alt=20, tz=-6, dst='A'),
#  Row(faa='ABE', name='Lehigh Valley Intl', lat=40.652083, lon=-75.440806, alt=393, tz=-5, dst='A'),
#  Row(faa='ABI', name='Abilene Rgnl', lat=32.411319, lon=-99.681897, alt=1791, tz=-6, dst='A'),
#  Row(faa='ABL', name='Ambler Airport', lat=67.106389, lon=-157.8575, alt=334, tz=-9, dst='A'),
#  Row(faa='ABQ', name='Albuquerque International Sunport', lat=35.0402222, lon=-106.6091944, alt=5355, tz=-7, dst='A'),
#  Row(faa='ABR', name='Aberdeen Regional Airport', lat=45.4491, lon=-98.4218, alt=1302, tz=-6, dst='A'),
#  Row(faa='ABY', name='Southwest Georgia Regional Airport', lat=31.5355, lon=-84.1945, alt=197, tz=-5, dst='A'),
#  Row(faa='ACK', name='Nantucket Mem', lat=41.253053, lon=-70.060181, alt=48, tz=-5, dst='A'),
#  Row(faa='ACT', name='Waco Rgnl', lat=31.611289, lon=-97.230519, alt=516, tz=-6, dst='A'),
#  Row(faa='ACV', name='Arcata', lat=40.978111, lon=-124.108611, alt=221, tz=-8, dst='A'),
#  Row(faa='ACY', name='Atlantic City Intl', lat=39.457583, lon=-74.577167, alt=75, tz=-5, dst='A'),
#  Row(faa='ADK', name='Adak Airport', lat=51.878, lon=-176.646, alt=18, tz=-10, dst='A'),
#  Row(faa='ADM', name='Ardmore Muni', lat=34.300833, lon=-97.008889, alt=762, tz=-6, dst='A'),
#  Row(faa='ADQ', name='Kodiak', lat=57.749967, lon=-152.493856, alt=78, tz=-9, dst='A'),
#  Row(faa='ADS', name='Addison', lat=32.9685594, lon=-96.8364478, alt=644, tz=-5, dst='A'),
#  Row(faa='ADW', name='Andrews Afb', lat=38.810806, lon=-76.867028, alt=280, tz=-5, dst='A'),
#  Row(faa='AET', name='Allakaket Airport', lat=66.5519, lon=-152.6222, alt=441, tz=-8, dst='A'),
#  Row(faa='AEX', name='Alexandria Intl', lat=31.3274, lon=-92.549833, alt=89, tz=-6, dst='A'),
#  Row(faa='AFE', name='Kake Airport', lat=56.961389, lon=-133.910278, alt=172, tz=-9, dst='A'),
#  Row(faa='AFW', name='Fort Worth Alliance Airport', lat=32.987778, lon=-97.318889, alt=722, tz=-6, dst='A'),
#  Row(faa='AGC', name='Allegheny County Airport', lat=40.3544, lon=-79.9302, alt=1252, tz=-5, dst='A'),
#  Row(faa='AGN', name='Angoon Seaplane Base', lat=57.503611, lon=-134.585, alt=0, tz=-9, dst='A'),
#  Row(faa='AGS', name='Augusta Rgnl At Bush Fld', lat=33.369944, lon=-81.9645, alt=144, tz=-5, dst='A'),
#  Row(faa='AHN', name='Athens Ben Epps Airport', lat=33.9486, lon=-83.3263, alt=808, tz=-5, dst='A'),
#  Row(faa='AIA', name='Alliance Municipal Airport', lat=42.053333, lon=-102.803889, alt=3931, tz=-7, dst='A'),
#  Row(faa='AIK', name='Municipal Airport', lat=33.6493889, lon=-81.6850278, alt=529, tz=-5, dst='A'),
#  Row(faa='AIN', name='Wainwright Airport', lat=70.638056, lon=-159.994722, alt=41, tz=-9, dst='A'),
#  Row(faa='AIZ', name='Lee C Fine Memorial Airport', lat=38.096035, lon=-92.5494875, alt=869, tz=-5, dst='A'),
#  Row(faa='AKB', name='Atka Airport', lat=52.220278, lon=-174.206389, alt=56, tz=-9, dst='A'),
#  Row(faa='AKC', name='Akron Fulton Intl', lat=41.0375, lon=-81.466917, alt=1067, tz=-5, dst='A'),
#  Row(faa='AKI', name='Akiak Airport', lat=60.902778, lon=-161.230556, alt=30, tz=-9, dst='A'),
#  Row(faa='AKK', name='Akhiok Airport', lat=56.938611, lon=-154.1825, alt=44, tz=-9, dst='A'),
#  Row(faa='AKN', name='King Salmon', lat=58.676778, lon=-156.649278, alt=68, tz=-9, dst='A'),
#  Row(faa='AKP', name='Anaktuvuk Pass Airport', lat=68.1336, lon=-151.743, alt=2103, tz=-9, dst='A'),
#  Row(faa='ALB', name='Albany Intl', lat=42.748267, lon=-73.801692, alt=285, tz=-5, dst='A'),
#  Row(faa='ALI', name='Alice Intl', lat=27.740889, lon=-98.026944, alt=178, tz=-6, dst='A'),
#  Row(faa='ALM', name='Alamogordo White Sands Regional Airport', lat=32.8399, lon=-105.991, alt=4200, tz=-7, dst='A'),
#  Row(faa='ALO', name='Waterloo Regional Airport', lat=42.5571, lon=-92.4003, alt=873, tz=-6, dst='A'),
#  Row(faa='ALS', name='San Luis Valley Regional Airport', lat=37.435, lon=-105.866667, alt=7539, tz=-7, dst='A'),
#  Row(faa='ALW', name='Walla Walla Regional Airport', lat=46.0949, lon=-118.288, alt=1191, tz=-8, dst='A'),
#  Row(faa='ALX', name='Alexandria', lat=38.806346, lon=-77.0621, alt=1, tz=-5, dst='A'),
#  Row(faa='ALZ', name='Alitak Seaplane Base', lat=56.899444, lon=-154.247778, alt=0, tz=-9, dst='A'),
#  Row(faa='AMA', name='Rick Husband Amarillo Intl', lat=35.219369, lon=-101.705931, alt=3607, tz=-6, dst='A'),
#  Row(faa='ANB', name='Anniston Metro', lat=33.588167, lon=-85.858111, alt=612, tz=-6, dst='A'),
#  Row(faa='ANC', name='Ted Stevens Anchorage Intl', lat=61.174361, lon=-149.996361, alt=152, tz=-9, dst='A'),
#  Row(faa='AND', name='Anderson Rgnl', lat=34.494583, lon=-82.709389, alt=782, tz=-5, dst='A'),
#  Row(faa='ANI', name='Aniak Airport', lat=61.5816, lon=-159.543, alt=88, tz=-9, dst='A'),
#  Row(faa='ANN', name='Annette Island', lat=55.042436, lon=-131.572233, alt=119, tz=-9, dst='A'),
#  Row(faa='ANP', name='Lee Airport', lat=38.942778, lon=-76.568333, alt=34, tz=-5, dst='A'),
#  Row(faa='ANQ', name='Tri-State Steuben County Airport', lat=41.6396983, lon=-85.0834933, alt=995, tz=-5, dst='A'),
#  Row(faa='ANV', name='Anvik Airport', lat=62.6467, lon=-160.191, alt=309, tz=-9, dst='A'),
#  Row(faa='AOH', name='Lima Allen County Airport', lat=40.707478, lon=-84.0270781, alt=975, tz=-5, dst='A'),
#  Row(faa='AOO', name='Altoona Blair Co', lat=40.296372, lon=-78.320022, alt=1504, tz=-5, dst='A'),
#  Row(faa='AOS', name='Amook Bay Seaplane Base', lat=57.471389, lon=-153.815278, alt=0, tz=-9, dst='A'),
#  Row(faa='APA', name='Centennial', lat=39.570129, lon=-104.849294, alt=5883, tz=-7, dst='A'),
#  Row(faa='APC', name='Napa County Airport', lat=38.2131944, lon=-122.2806944, alt=35, tz=-7, dst='A'),
#  Row(faa='APF', name='Naples Muni', lat=26.152619, lon=-81.775294, alt=8, tz=-5, dst='A'),
#  Row(faa='APG', name='Phillips Aaf', lat=39.466219, lon=-76.168808, alt=57, tz=-5, dst='A'),
#  Row(faa='APN', name='Alpena County Regional Airport', lat=45.0781, lon=-83.5603, alt=689, tz=-5, dst='A'),
#  Row(faa='AQC', name='Klawock Seaplane Base', lat=55.554658, lon=-133.101693, alt=0, tz=-9, dst='A'),
#  Row(faa='ARA', name='Acadiana Rgnl', lat=30.037758, lon=-91.883896, alt=24, tz=-6, dst='A'),
#  Row(faa='ARB', name='Ann Arbor Municipal Airport', lat=42.132274, lon=-83.444418, alt=839, tz=-5, dst='A'),
#  Row(faa='ARC', name='Arctic Village Airport', lat=68.1147, lon=-145.579, alt=2092, tz=-9, dst='A'),
#  Row(faa='ART', name='Watertown Intl', lat=43.991922, lon=-76.021739, alt=325, tz=-5, dst='A'),
#  Row(faa='ARV', name='Lakeland', lat=45.927778, lon=-89.730833, alt=1629, tz=-6, dst='A'),
#  Row(faa='ASE', name='Aspen Pitkin County Sardy Field', lat=39.2232, lon=-106.869, alt=7820, tz=-7, dst='A'),
#  Row(faa='ASH', name='Boire Field Airport', lat=42.78175, lon=-71.5147778, alt=199, tz=-4, dst='A'),
#  Row(faa='AST', name='Astoria Regional Airport', lat=46.157972, lon=-123.878694, alt=15, tz=-8, dst='A'),
#  Row(faa='ATK', name='Atqasuk Edward Burnell Sr Memorial Airport', lat=70.4673, lon=-157.436, alt=96, tz=-9, dst='A'),
#  Row(faa='ATL', name='Hartsfield Jackson Atlanta Intl', lat=33.636719, lon=-84.428067, alt=1026, tz=-5, dst='A'),
#  Row(faa='ATT', name='Camp Mabry Austin City', lat=30.31666, lon=-97.7666, alt=0, tz=-6, dst='A'),
#  Row(faa='ATW', name='Appleton', lat=44.257526, lon=-88.507576, alt=680, tz=-6, dst='A'),
#  Row(faa='ATY', name='Watertown Regional Airport', lat=44.914, lon=-97.1547, alt=1748, tz=-6, dst='A'),
#  Row(faa='AUG', name='Augusta State', lat=44.320647, lon=-69.797317, alt=352, tz=-5, dst='A'),
#  Row(faa='AUK', name='Alakanuk Airport', lat=62.68, lon=-164.66, alt=10, tz=-9, dst='A'),
#  Row(faa='AUS', name='Austin Bergstrom Intl', lat=30.194528, lon=-97.669889, alt=542, tz=-6, dst='A'),
#  Row(faa='AUW', name='Wausau Downtown Airport', lat=44.9262845, lon=-89.6270018, alt=1201, tz=-6, dst='U'),
#  Row(faa='AVL', name='Asheville Regional Airport', lat=35.436194, lon=-82.541806, alt=2165, tz=-5, dst='A'),
#  Row(faa='AVO', name='Executive', lat=27.591389, lon=-81.528889, alt=160, tz=-5, dst='A'),
#  Row(faa='AVP', name='Wilkes Barre Scranton Intl', lat=41.338478, lon=-75.723403, alt=962, tz=-5, dst='A'),
#  Row(faa='AVW', name='Marana Regional', lat=32.409556, lon=-111.218388, alt=2031, tz=-7, dst='U'),
#  Row(faa='AVX', name='Avalon', lat=33.405, lon=-118.415833, alt=1602, tz=-8, dst='A'),
#  Row(faa='AZA', name='Phoenix-Mesa Gateway', lat=33.307833, lon=-111.655, alt=1382, tz=-7, dst='N'),
#  Row(faa='AZO', name='Kalamazoo', lat=42.234875, lon=-85.552058, alt=874, tz=-5, dst='A'),
#  Row(faa='BAB', name='Beale Afb', lat=39.136089, lon=-121.436567, alt=113, tz=-8, dst='A'),
#  Row(faa='BAD', name='Barksdale Afb', lat=32.50182, lon=-93.662674, alt=166, tz=-6, dst='A'),
#  Row(faa='BAF', name='Barnes Municipal', lat=42.1579472, lon=-72.715875, alt=270, tz=-4, dst='A'),
#  Row(faa='BBX', name='Wings Field', lat=40.1375, lon=-75.265, alt=302, tz=-5, dst='A'),
#  Row(faa='BCE', name='Bryce Canyon', lat=37.706444, lon=-112.145806, alt=7590, tz=-7, dst='A'),
#  Row(faa='BCT', name='Boca Raton', lat=26.3785, lon=-80.107694, alt=13, tz=-5, dst='A'),
#  Row(faa='BDE', name='Baudette Intl', lat=48.728444, lon=-94.612222, alt=1086, tz=-6, dst='A'),
#  Row(faa='BDL', name='Bradley Intl', lat=41.938889, lon=-72.683222, alt=173, tz=-5, dst='A'),
#  Row(faa='BDR', name='Igor I Sikorsky Mem', lat=41.163472, lon=-73.126167, alt=9, tz=-5, dst='A'),
#  Row(faa='BEC', name='Beech Factory Airport', lat=37.6939167, lon=-97.2149167, alt=1409, tz=-5, dst='A'),
#  Row(faa='BED', name='Laurence G Hanscom Fld', lat=42.469953, lon=-71.289031, alt=133, tz=-5, dst='A'),
#  Row(faa='BEH', name='Southwest Michigan Regional Airport', lat=42.1285833, lon=-86.4285, alt=643, tz=-5, dst='A'),
#  Row(faa='BET', name='Bethel', lat=60.779778, lon=-161.838, alt=121, tz=-9, dst='A'),
#  Row(faa='BFD', name='Bradford Regional Airport', lat=41.8031, lon=-78.6401, alt=2143, tz=-5, dst='A'),
#  Row(faa='BFF', name='Western Nebraska Regional Airport', lat=41.874, lon=-103.596, alt=3967, tz=-7, dst='A'),
#  Row(faa='BFI', name='Boeing Fld King Co Intl', lat=47.53, lon=-122.301947, alt=21, tz=-8, dst='A'),
#  Row(faa='BFL', name='Meadows Fld', lat=35.433598, lon=-119.05677, alt=507, tz=-8, dst='A'),
#  Row(faa='BFM', name='Mobile Downtown', lat=30.626783, lon=-88.068092, alt=26, tz=-6, dst='A'),
#  Row(faa='BFP', name='Beaver Falls', lat=40.7724722, lon=-80.3914444, alt=1253, tz=-4, dst='A'),
#  Row(faa='BFT', name='Beaufort', lat=32.477411, lon=-80.723161, alt=37, tz=-5, dst='A'),
#  Row(faa='BFT', name='BFT County Airport', lat=32.41083, lon=-80.635, alt=500, tz=-5, dst='A'),
#  Row(faa='BGE', name='Decatur County Industrial Air Park', lat=30.9715981, lon=-84.6369278, alt=141, tz=-5, dst='A'),
#  Row(faa='BGM', name='Greater Binghamton Edwin A Link Fld', lat=42.208689, lon=-75.979839, alt=1636, tz=-5, dst='A'),
#  Row(faa='BGR', name='Bangor Intl', lat=44.807444, lon=-68.828139, alt=192, tz=-5, dst='A'),
#  Row(faa='BHB', name='Hancock County - Bar Harbor', lat=44.4497689, lon=-68.3615653, alt=83, tz=-5, dst='A'),
#  Row(faa='BHM', name='Birmingham Intl', lat=33.562942, lon=-86.75355, alt=644, tz=-6, dst='A'),
#  Row(faa='BID', name='Block Island State Airport', lat=41.168056, lon=-71.577778, alt=108, tz=-5, dst='A'),
#  Row(faa='BIF', name='Biggs Aaf', lat=31.849528, lon=-106.380039, alt=3948, tz=-7, dst='A'),
#  Row(faa='BIG', name='Allen Aaf', lat=63.994547, lon=-145.721642, alt=1291, tz=-9, dst='A'),
#  Row(faa='BIL', name='Billings Logan International Airport', lat=45.80921, lon=-108.537654, alt=3652, tz=-7, dst='A'),
#  Row(faa='BIS', name='Bismarck Municipal Airport', lat=46.775842, lon=-100.757931, alt=1661, tz=-6, dst='A'),
#  Row(faa='BIV', name='Tulip City Airport', lat=42.7427778, lon=-86.1078333, alt=698, tz=-5, dst='A'),
#  Row(faa='BIX', name='Keesler Afb', lat=30.410425, lon=-88.924433, alt=33, tz=-6, dst='A'),
#  Row(faa='BJC', name='Rocky Mountain Metropolitan Airport', lat=39.90888888, lon=-105.11722222, alt=5670, tz=-7, dst='A'),
#  Row(faa='BJI', name='Bemidji Regional Airport', lat=47.510722, lon=-94.934722, alt=1391, tz=-6, dst='A'),
#  Row(faa='BKC', name='Buckland Airport', lat=65.981667, lon=-161.149167, alt=31, tz=-9, dst='A'),
#  Row(faa='BKD', name='Stephens Co', lat=32.719047, lon=-98.891, alt=1284, tz=-6, dst='A'),
#  Row(faa='BKF', name='Buckley Afb', lat=39.701668, lon=-104.75166, alt=5662, tz=-7, dst='A'),
#  Row(faa='BKG', name='Branson LLC', lat=36.531994, lon=-93.200556, alt=1302, tz=-6, dst='A'),
#  Row(faa='BKH', name='Barking Sands Pmrf', lat=22.022833, lon=-159.785, alt=23, tz=-10, dst='A'),
#  Row(faa='BKL', name='Burke Lakefront Airport', lat=41.5175, lon=-81.683333, alt=583, tz=-5, dst='A'),
#  Row(faa='BKW', name='Raleigh County Memorial Airport', lat=37.7873, lon=-81.1242, alt=2504, tz=-5, dst='A'),
#  Row(faa='BKX', name='Brookings Regional Airport', lat=44.3048, lon=-96.8169, alt=1648, tz=-6, dst='A'),
#  Row(faa='BLD', name='Boulder City Municipal Airport', lat=35.5651, lon=-114.514, alt=2201, tz=-8, dst='U'),
#  Row(faa='BLF', name='Mercer County Airport', lat=37.2958, lon=-81.2077, alt=2857, tz=-5, dst='A'),
#  Row(faa='BLH', name='Blythe Airport', lat=33.619167, lon=-114.716889, alt=399, tz=-8, dst='A'),
#  Row(faa='BLI', name='Bellingham Intl', lat=48.792694, lon=-122.537528, alt=170, tz=-8, dst='A'),
#  Row(faa='BLV', name='Scott Afb Midamerica', lat=38.545178, lon=-89.835183, alt=459, tz=-6, dst='A'),
#  Row(faa='BMC', name='Brigham City', lat=41.552, lon=-112.062, alt=4229, tz=-7, dst='A'),
#  Row(faa='BMG', name='Monroe County Airport', lat=39.1460208, lon=-86.6166805, alt=846, tz=-5, dst='A'),
#  Row(faa='BMI', name='Central Illinois Rgnl', lat=40.477111, lon=-88.915917, alt=871, tz=-6, dst='A'),
#  Row(faa='BMX', name='Big Mountain Afs', lat=59.361247, lon=-155.258822, alt=663, tz=-9, dst='A'),
#  Row(faa='BNA', name='Nashville Intl', lat=36.124472, lon=-86.678194, alt=599, tz=-6, dst='A'),
#  Row(faa='BOI', name='Boise Air Terminal', lat=43.564361, lon=-116.222861, alt=2871, tz=-7, dst='A'),
#  Row(faa='BOS', name='General Edward Lawrence Logan Intl', lat=42.364347, lon=-71.005181, alt=19, tz=-5, dst='A'),
#  Row(faa='BOW', name='Bartow Municipal Airport', lat=27.9434, lon=-81.7834, alt=125, tz=-6, dst='U'),
#  Row(faa='BPT', name='Southeast Texas Rgnl', lat=29.950833, lon=-94.020694, alt=15, tz=-6, dst='A'),
#  Row(faa='BQK', name='Brunswick Golden Isles Airport', lat=31.2588, lon=-81.4665, alt=26, tz=-5, dst='A'),
#  Row(faa='BRD', name='Brainerd Lakes Rgnl', lat=46.398308, lon=-94.138078, alt=1226, tz=-6, dst='U'),
#  Row(faa='BRL', name='Southeast Iowa Regional Airport', lat=40.7832, lon=-91.1255, alt=698, tz=-6, dst='A'),
#  Row(faa='BRO', name='Brownsville South Padre Island Intl', lat=25.906833, lon=-97.425861, alt=22, tz=-6, dst='A'),
#  Row(faa='BRW', name='Wiley Post Will Rogers Mem', lat=71.285446, lon=-156.766003, alt=44, tz=-9, dst='A'),
#  Row(faa='BSF', name='Bradshaw Aaf', lat=19.760056, lon=-155.553717, alt=6190, tz=-10, dst='A'),
#  Row(faa='BTI', name='Barter Island Lrrs', lat=70.133989, lon=-143.581867, alt=2, tz=-9, dst='A'),
#  Row(faa='BTM', name='Bert Mooney Airport', lat=45.954806, lon=-112.497472, alt=5550, tz=-7, dst='A'),
#  Row(faa='BTR', name='Baton Rouge Metro Ryan Fld', lat=30.533167, lon=-91.149639, alt=70, tz=-6, dst='A'),
#  Row(faa='BTT', name='Bettles', lat=66.913944, lon=-151.529056, alt=644, tz=-9, dst='A'),
#  Row(faa='BTV', name='Burlington Intl', lat=44.471861, lon=-73.153278, alt=335, tz=-5, dst='A'),
#  Row(faa='BUF', name='Buffalo Niagara Intl', lat=42.940525, lon=-78.732167, alt=724, tz=-5, dst='A'),
#  Row(faa='BUR', name='Bob Hope', lat=34.200667, lon=-118.358667, alt=778, tz=-8, dst='A'),
#  Row(faa='BUU', name='Municipal Airport', lat=42.6907171, lon=-88.3046825, alt=780, tz=-6, dst='A'),
#  Row(faa='BUY', name='Burlington-Alamance Regional Airport', lat=36.0485433, lon=-79.4748892, alt=617, tz=-4, dst='A'),
#  Row(faa='BVY', name='Beverly Municipal Airport', lat=42.584141, lon=-70.9161444, alt=107, tz=-5, dst='A'),
#  Row(faa='BWD', name='KBWD', lat=31.7936111, lon=-98.9565, alt=1387, tz=-6, dst='A'),
#  Row(faa='BWG', name='Bowling Green-Warren County Regional Airport', lat=36.9645278, lon=-86.4196667, alt=547, tz=-5, dst='A'),
#  Row(faa='BWI', name='Baltimore Washington Intl', lat=39.175361, lon=-76.668333, alt=146, tz=-5, dst='A'),
#  Row(faa='BXK', name='Buckeye Municipal Airport', lat=33.420417, lon=-112.68618, alt=1033, tz=-7, dst='U'),
#  Row(faa='BXS', name='Borrego Valley Airport', lat=33.2590278, lon=-116.3209722, alt=520, tz=-7, dst='A'),
#  Row(faa='BYH', name='Arkansas Intl', lat=35.964347, lon=-89.943956, alt=254, tz=-6, dst='A'),
#  Row(faa='BYS', name='Bicycle Lake Aaf', lat=35.280531, lon=-116.630031, alt=2350, tz=-8, dst='A'),
#  Row(faa='BYW', name='Blakely Island Airport', lat=48.56025, lon=-122.80243, alt=0, tz=-8, dst='A'),
#  Row(faa='BZN', name='Gallatin Field', lat=45.777643, lon=-111.160151, alt=4500, tz=-7, dst='A'),
#  Row(faa='C02', name='Grand Geneva Resort Airport', lat=42.6149167, lon=-88.3895833, alt=835, tz=-6, dst='U'),
#  Row(faa='C16', name='Frasca Field', lat=40.144979, lon=-88.200197, alt=735, tz=-6, dst='A'),
#  Row(faa='C47', name='Portage Municipal Airport', lat=43.5603136, lon=-89.4828607, alt=825, tz=-6, dst='U'),
#  Row(faa='C65', name='Plymouth Municipal Airport', lat=41.3651307, lon=-86.3002574, alt=800, tz=-5, dst='A'),
#  Row(faa='C89', name='Sylvania Airport', lat=42.70325, lon=-87.9589722, alt=785, tz=-6, dst='A'),
#  Row(faa='C91', name='Dowagiac Municipal Airport', lat=41.9929342, lon=-86.1280125, alt=748, tz=-5, dst='U'),
#  Row(faa='CAE', name='Columbia Metropolitan', lat=33.938833, lon=-81.119528, alt=236, tz=-5, dst='A'),
#  Row(faa='CAK', name='Akron Canton Regional Airport', lat=40.9160833, lon=-81.4421944, alt=1228, tz=-5, dst='A'),
#  Row(faa='CAR', name='Caribou Muni', lat=46.8715, lon=-68.017917, alt=626, tz=-4, dst='A'),
#  Row(faa='CBE', name='Greater Cumberland Rgnl.', lat=39.615278, lon=-78.760556, alt=775, tz=-5, dst='A'),
#  Row(faa='CBM', name='Columbus Afb', lat=33.643833, lon=-88.443833, alt=219, tz=-6, dst='A'),
#  Row(faa='CCO', name='Coweta County Airport', lat=33.3115656, lon=-84.7697554, alt=970, tz=-5, dst='A'),
#  Row(faa='CCR', name='Buchanan Field Airport', lat=37.9896667, lon=-122.0568889, alt=26, tz=-8, dst='A'),
#  Row(faa='CDB', name='Cold Bay', lat=55.206061, lon=-162.725436, alt=96, tz=-9, dst='A'),
#  Row(faa='CDC', name='Cedar City Rgnl', lat=37.700967, lon=-113.098847, alt=5622, tz=-7, dst='A'),
#  Row(faa='CDI', name='Cambridge Municipal Airport', lat=39.9750278, lon=-81.5775833, alt=799, tz=-5, dst='U'),
#  Row(faa='CDK', name='CedarKey', lat=29.1342222, lon=-83.0504722, alt=11, tz=-4, dst='A'),
#  Row(faa='CDN', name='Woodward Field', lat=34.2835833, lon=-80.5648611, alt=302, tz=-5, dst='A'),
#  Row(faa='CDR', name='Chadron Municipal Airport', lat=42.8375, lon=-103.095556, alt=3297, tz=-7, dst='A'),
#  Row(faa='CDS', name='Childress Muni', lat=34.433781, lon=-100.287992, alt=1954, tz=-6, dst='A'),
#  Row(faa='CDV', name='Merle K Mudhole Smith', lat=60.491778, lon=-145.477556, alt=48, tz=-9, dst='A'),
#  Row(faa='CDW', name='Caldwell Essex County Airport', lat=40.8752222, lon=-74.2813611, alt=172, tz=-5, dst='A'),
#  Row(faa='CEC', name='Del Norte County Airport', lat=41.7802, lon=-124.237, alt=57, tz=-8, dst='A'),
#  Row(faa='CEF', name='Westover Arb Metropolitan', lat=42.194014, lon=-72.534783, alt=241, tz=-5, dst='A'),
#  Row(faa='CEM', name='Central Airport', lat=65.573889, lon=-144.780833, alt=937, tz=-9, dst='A'),
#  Row(faa='CEU', name='Clemson', lat=34.6722222, lon=-82.8858889, alt=891, tz=-4, dst='A'),
#  Row(faa='CEW', name='Bob Sikes', lat=30.778833, lon=-86.522111, alt=213, tz=-6, dst='A'),
#  Row(faa='CEZ', name='Cortez Muni', lat=37.303, lon=-108.628056, alt=5918, tz=-7, dst='A'),
#  Row(faa='CFD', name='Coulter Fld', lat=30.715694, lon=-96.331361, alt=367, tz=-6, dst='A'),
#  Row(faa='CGA', name='Craig Seaplane Base', lat=55.478889, lon=-133.147778, alt=0, tz=-9, dst='A'),
#  Row(faa='CGF', name='Cuyahoga County', lat=41.565124, lon=-81.4863555, alt=879, tz=-5, dst='A'),
#  Row(faa='CGI', name='Cape Girardeau Regional Airport', lat=37.2253, lon=-89.5708, alt=342, tz=-6, dst='A'),
#  Row(faa='CGX', name='Meigs Field', lat=41.860278, lon=-87.609722, alt=585, tz=-6, dst='A'),
#  Row(faa='CGZ', name='Casa Grande Municipal Airport', lat=32.954889, lon=-111.766832, alt=1464, tz=-7, dst='U'),
#  Row(faa='CHA', name='Lovell Fld', lat=35.035278, lon=-85.203808, alt=683, tz=-5, dst='A'),
#  Row(faa='CHI', name='All Airports', lat=41.883611, lon=-87.631667, alt=596, tz=-6, dst='A'),
#  Row(faa='CHO', name='Charlottesville-Albemarle', lat=38.138639, lon=-78.452861, alt=639, tz=-5, dst='A'),
#  Row(faa='CHS', name='Charleston Afb Intl', lat=32.898647, lon=-80.040528, alt=45, tz=-5, dst='A'),
#  Row(faa='CHU', name='Chuathbaluk Airport', lat=61.579167, lon=-159.215556, alt=243, tz=-9, dst='A'),
#  Row(faa='CIC', name='Chico Muni', lat=39.795383, lon=-121.858422, alt=238, tz=-8, dst='A'),
#  Row(faa='CID', name='Cedar Rapids', lat=41.884694, lon=-91.710806, alt=869, tz=-6, dst='A'),
#  Row(faa='CIK', name='Chalkyitsik Airport', lat=66.645, lon=-143.74, alt=544, tz=-9, dst='A'),
#  Row(faa='CIL', name='Council Airport', lat=64.897778, lon=-163.703333, alt=85, tz=-9, dst='A'),
#  Row(faa='CIU', name='Chippewa County International Airport', lat=46.2508, lon=-84.4724, alt=800, tz=-5, dst='A'),
#  Row(faa='CKB', name='Harrison Marion Regional Airport', lat=39.2966, lon=-80.2281, alt=1217, tz=-5, dst='A'),
#  Row(faa='CKD', name='Crooked Creek Airport', lat=61.867778, lon=-158.135, alt=178, tz=-9, dst='A'),
#  Row(faa='CKF', name='Crisp County Cordele Airport', lat=31.9888333, lon=-83.7739167, alt=310, tz=-5, dst='A'),
#  Row(faa='CKV', name='Clarksville-Montgomery County Regional Airport', lat=36.621944, lon=-87.415, alt=550, tz=-5, dst='A'),
#  Row(faa='CLC', name='Clear Lake Metroport', lat=29.5569, lon=-95.137497, alt=35, tz=6, dst='A'),
#  Row(faa='CLD', name='McClellan-Palomar Airport', lat=33.0742, lon=-117.1648, alt=328, tz=-8, dst='A'),
#  Row(faa='CLE', name='Cleveland Hopkins Intl', lat=41.411689, lon=-81.849794, alt=791, tz=-5, dst='A'),
#  Row(faa='CLL', name='Easterwood Fld', lat=30.588583, lon=-96.363833, alt=321, tz=-6, dst='A'),
#  Row(faa='CLM', name='William R Fairchild International Airport', lat=48.1202, lon=-123.5, alt=291, tz=-8, dst='A'),
#  Row(faa='CLT', name='Charlotte Douglas Intl', lat=35.214, lon=-80.943139, alt=748, tz=-5, dst='A'),
#  Row(faa='CLW', name='Clearwater Air Park', lat=27.9764722, lon=-82.7586667, alt=70, tz=-5, dst='A'),
#  Row(faa='CMH', name='Port Columbus Intl', lat=39.997972, lon=-82.891889, alt=815, tz=-5, dst='A'),
#  Row(faa='CMI', name='Champaign', lat=40.03925, lon=-88.278056, alt=754, tz=-6, dst='A'),
#  Row(faa='CMX', name='Houghton County Memorial Airport', lat=47.1684, lon=-88.4891, alt=1095, tz=-5, dst='A'),
#  Row(faa='CNM', name='Cavern City Air Terminal', lat=32.337472, lon=-104.263278, alt=3295, tz=-7, dst='A'),
#  Row(faa='CNW', name='Tstc Waco', lat=31.637831, lon=-97.074139, alt=470, tz=-6, dst='A'),
#  Row(faa='CNY', name='Canyonlands Field', lat=38.755, lon=-109.754722, alt=4555, tz=-7, dst='A'),
#  Row(faa='COD', name='Yellowstone Rgnl', lat=44.520194, lon=-109.023806, alt=5102, tz=-7, dst='A'),
#  Row(faa='COF', name='Patrick Afb', lat=28.234922, lon=-80.610125, alt=8, tz=-5, dst='A'),
#  Row(faa='CON', name='Concord Municipal', lat=43.20267, lon=-71.50233, alt=342, tz=-5, dst='A'),
#  Row(faa='COS', name='City Of Colorado Springs Muni', lat=38.805805, lon=-104.700778, alt=6187, tz=-7, dst='A'),
#  Row(faa='COT', name='Cotulla Lasalle Co', lat=28.456694, lon=-99.220294, alt=474, tz=-6, dst='A'),
#  Row(faa='COU', name='Columbia Rgnl', lat=38.818094, lon=-92.219631, alt=889, tz=-6, dst='A'),
#  Row(faa='CPR', name='Natrona Co Intl', lat=42.908, lon=-106.464417, alt=5347, tz=-7, dst='A'),
#  Row(faa='CPS', name='St. Louis Downtown Airport', lat=38.5707244, lon=-90.1562211, alt=413, tz=-6, dst='U'),
#  Row(faa='CRE', name='Grand Strand Airport', lat=33.81175, lon=-78.7239444, alt=31, tz=-4, dst='A'),
#  Row(faa='CRP', name='Corpus Christi Intl', lat=27.770361, lon=-97.501222, alt=44, tz=-6, dst='A'),
#  Row(faa='CRW', name='Yeager', lat=38.373147, lon=-81.593189, alt=981, tz=-5, dst='A'),
#  Row(faa='CSG', name='Columbus Metropolitan Airport', lat=32.5163333, lon=-84.9388611, alt=397, tz=-5, dst='A'),
#  Row(faa='CTB', name='Cut Bank Muni', lat=48.608353, lon=-112.376144, alt=3854, tz=-7, dst='A'),
#  Row(faa='CTH', name='Chester County G O Carlson Airport', lat=39.9789, lon=-75.8654, alt=660, tz=-5, dst='A'),
#  Row(faa='CTJ', name='West Georgia Regional Airport - O V Gray Field', lat=33.6316964, lon=-85.1522641, alt=1165, tz=-4, dst='A'),
#  Row(faa='CTY', name='Cross City', lat=29.6355278, lon=-83.10475, alt=42, tz=-4, dst='A'),
#  Row(faa='CVG', name='Cincinnati Northern Kentucky Intl', lat=39.048836, lon=-84.667822, alt=896, tz=-5, dst='A'),
#  Row(faa='CVN', name='Clovis Muni', lat=34.425139, lon=-103.079278, alt=4216, tz=-6, dst='A'),
#  Row(faa='CVS', name='Cannon Afb', lat=34.382775, lon=-103.322147, alt=4295, tz=-7, dst='A'),
#  Row(faa='CVX', name='Charlevoix Municipal Airport', lat=45.3047778, lon=-85.2753333, alt=669, tz=-5, dst='A'),
#  Row(faa='CWA', name='Central Wisconsin', lat=44.772726, lon=-89.646635, alt=840, tz=-6, dst='A'),
#  Row(faa='CWI', name='Clinton Municipal', lat=41.83075, lon=-90.3289722, alt=708, tz=-6, dst='A'),
#  Row(faa='CXF', name='Coldfoot Airport', lat=67.251389, lon=-150.176111, alt=1014, tz=-9, dst='A'),
#  Row(faa='CXL', name='Calexico Intl', lat=32.669502, lon=-115.51333, alt=4, tz=-8, dst='A'),
#  Row(faa='CXO', name='Lone Star Executive', lat=30.351833, lon=-95.414467, alt=245, tz=-6, dst='A'),
#  Row(faa='CXY', name='Capital City Airport', lat=40.2171389, lon=-76.8513611, alt=347, tz=-5, dst='A'),
#  Row(faa='CYF', name='Chefornak Airport', lat=60.149167, lon=-164.285556, alt=40, tz=-9, dst='A'),
#  Row(faa='CYM', name='Chatham Seaplane Base', lat=57.515, lon=-134.946111, alt=0, tz=-9, dst='A'),
#  Row(faa='CYS', name='Cheyenne Rgnl Jerry Olson Fld', lat=41.155722, lon=-104.811839, alt=6156, tz=-7, dst='A'),
#  Row(faa='CYT', name='Yakataga Airport', lat=60.081901, lon=-142.493611, alt=12, tz=-9, dst='A'),
#  Row(faa='CZF', name='Cape Romanzof Lrrs', lat=61.780297, lon=-166.038747, alt=457, tz=-9, dst='A'),
#  Row(faa='CZN', name='Chisana Airport', lat=62.071111, lon=-142.048333, alt=1011, tz=-9, dst='A'),
#  Row(faa='DAB', name='Daytona Beach Intl', lat=29.179917, lon=-81.058056, alt=34, tz=-5, dst='A'),
#  Row(faa='DAL', name='Dallas Love Fld', lat=32.847111, lon=-96.851778, alt=487, tz=-6, dst='A'),
#  Row(faa='DAY', name='James M Cox Dayton Intl', lat=39.902375, lon=-84.219375, alt=1009, tz=-5, dst='A'),
#  Row(faa='DBQ', name='Dubuque Rgnl', lat=42.402, lon=-90.709472, alt=1076, tz=-6, dst='A'),
#  Row(faa='DCA', name='Ronald Reagan Washington Natl', lat=38.852083, lon=-77.037722, alt=15, tz=-5, dst='A'),
#  Row(faa='DDC', name='Dodge City Regional Airport', lat=37.7634, lon=-99.9656, alt=2594, tz=-6, dst='A'),
#  Row(faa='DEC', name='Decatur', lat=39.834564, lon=-88.865689, alt=682, tz=-6, dst='A'),
#  Row(faa='DEN', name='Denver Intl', lat=39.861656, lon=-104.673178, alt=5431, tz=-7, dst='A'),
#  Row(faa='DET', name='Coleman A Young Muni', lat=42.409195, lon=-83.009861, alt=626, tz=-5, dst='A'),
#  Row(faa='DFW', name='Dallas Fort Worth Intl', lat=32.896828, lon=-97.037997, alt=607, tz=-6, dst='A'),
#  Row(faa='DGL', name='Douglas Municipal Airport', lat=31.3426028, lon=-109.5064544, alt=4173, tz=-7, dst='N'),
#  Row(faa='DHN', name='Dothan Rgnl', lat=31.321339, lon=-85.449628, alt=401, tz=-6, dst='A'),
#  Row(faa='DHT', name='Dalhart Muni', lat=36.022586, lon=-102.547278, alt=3991, tz=-6, dst='A'),
#  Row(faa='DIK', name='Dickinson Theodore Roosevelt Regional Airport', lat=46.7975, lon=-102.801944, alt=2592, tz=-5, dst='A'),
#  Row(faa='DKB', name='De Kalb Taylor Municipal Airport', lat=41.9338342, lon=-88.7056864, alt=914, tz=-6, dst='U'),
#  Row(faa='DKK', name='Chautauqua County-Dunkirk Airport', lat=42.4933353, lon=-79.2720417, alt=693, tz=-5, dst='A'),
#  Row(faa='DKX', name='Knoxville Downtown Island Airport', lat=35.9638333, lon=-83.8736667, alt=833, tz=-4, dst='A'),
#  Row(faa='DLF', name='Laughlin Afb', lat=29.359486, lon=-100.777975, alt=1082, tz=-6, dst='A'),
#  Row(faa='DLG', name='Dillingham', lat=59.044667, lon=-158.5055, alt=74, tz=-9, dst='A'),
#  Row(faa='DLH', name='Duluth Intl', lat=46.842091, lon=-92.193649, alt=1428, tz=-6, dst='A'),
#  Row(faa='DLL', name='Baraboo Wisconsin Dells Airport', lat=43.5217843, lon=-89.7709266, alt=979, tz=-6, dst='A'),
#  Row(faa='DMA', name='Davis Monthan Afb', lat=32.166467, lon=-110.883144, alt=2704, tz=-7, dst='A'),
#  Row(faa='DNL', name='Daniel Field Airport', lat=33.4665028, lon=-82.0393808, alt=423, tz=-5, dst='A'),
#  Row(faa='DNN', name='Dalton Municipal Airport', lat=34.7229444, lon=-84.87025, alt=709, tz=-4, dst='A'),
#  Row(faa='DOV', name='Dover Afb', lat=39.129539, lon=-75.465958, alt=28, tz=-5, dst='A'),
#  Row(faa='DPA', name='Dupage', lat=41.907778, lon=-88.248611, alt=758, tz=-6, dst='A'),
#  Row(faa='DQH', name='Douglas Municipal Airport', lat=31.4767385, lon=-82.8605664, alt=257, tz=-5, dst='A'),
#  Row(faa='DRG', name='Deering Airport', lat=66.0696, lon=-162.766, alt=21, tz=-9, dst='A'),
#  Row(faa='DRI', name='Beauregard Rgnl', lat=30.831722, lon=-93.339917, alt=202, tz=-6, dst='A'),
#  Row(faa='DRM', name='Drummond Island Airport', lat=46.0093114, lon=-83.7439342, alt=668, tz=-5, dst='A'),
#  Row(faa='DRO', name='Durango La Plata Co', lat=37.151516, lon=-107.75377, alt=6685, tz=-7, dst='A'),
#  Row(faa='DRT', name='Del Rio Intl', lat=29.374208, lon=-100.927158, alt=1002, tz=-6, dst='A'),
#  Row(faa='DSM', name='Des Moines Intl', lat=41.533972, lon=-93.663083, alt=958, tz=-6, dst='A'),
#  Row(faa='DTA', name='Delta Municipal Airport', lat=39.3806386, lon=-112.5077147, alt=4759, tz=-6, dst='A'),
#  Row(faa='DTS', name='Destin', lat=30.4000611, lon=-86.4714772, alt=23, tz=-5, dst='A'),
#  Row(faa='DTW', name='Detroit Metro Wayne Co', lat=42.212444, lon=-83.353389, alt=645, tz=-5, dst='A'),
#  Row(faa='DUC', name='Halliburton Field Airport', lat=34.4713056, lon=-97.9598611, alt=1114, tz=-6, dst='A'),
#  Row(faa='DUG', name='Bisbee Douglas Intl', lat=31.469028, lon=-109.603667, alt=4154, tz=-7, dst='A'),
#  Row(faa='DUJ', name='DuBois Regional Airport', lat=41.1783, lon=-78.8987, alt=1817, tz=-5, dst='A'),
#  Row(faa='DUT', name='Unalaska', lat=53.900139, lon=-166.5435, alt=22, tz=-9, dst='A'),
#  Row(faa='DVL', name='Devils Lake Regional Airport', lat=48.114444, lon=-98.908611, alt=1445, tz=-6, dst='A'),
#  Row(faa='DVT', name='Deer Valley Municipal Airport', lat=33.4117, lon=112.457, alt=1478, tz=-7, dst='A'),
#  Row(faa='DWA', name='Yolo County Airport', lat=38.5793889, lon=-121.8569444, alt=100, tz=-7, dst='A'),
#  Row(faa='DWH', name='David Wayne Hooks Field', lat=30.063746, lon=-95.554276, alt=152, tz=-6, dst='A'),
#  Row(faa='DWS', name='Orlando', lat=28.398, lon=-81.57, alt=340, tz=-5, dst='A'),
#  Row(faa='DXR', name='Danbury Municipal Airport', lat=41.3715353, lon=-73.4821906, alt=458, tz=-5, dst='A'),
#  Row(faa='DYS', name='Dyess Afb', lat=32.420756, lon=-99.8546, alt=1789, tz=-6, dst='A'),
#  Row(faa='E25', name='Wickenburg Municipal Airport', lat=33.96889877, lon=-112.7990036, alt=2377, tz=-7, dst='A'),
#  Row(faa='E51', name='Bagdad Airport', lat=34.5958528, lon=-113.170195, alt=4183, tz=-7, dst='A'),
#  Row(faa='E55', name='Ocean Ridge Airport', lat=38.8016111, lon=-123.5306389, alt=940, tz=-8, dst='A'),
#  Row(faa='E63', name='Gila Bend Municipal Airport', lat=32.960169, lon=-112.673636, alt=789, tz=-7, dst='U'),
#  Row(faa='E91', name='Chinle Municipal Airport', lat=36.1108806, lon=-109.5754222, alt=5547, tz=-7, dst='N'),
#  Row(faa='EAA', name='Eagle Airport', lat=64.778056, lon=-141.149722, alt=908, tz=-9, dst='A'),
#  Row(faa='EAR', name='Kearney Municipal Airport', lat=40.727, lon=-99.0068, alt=2131, tz=-6, dst='A'),
#  Row(faa='EAT', name='Pangborn Field', lat=47.398, lon=-120.206, alt=1249, tz=-8, dst='A'),
#  Row(faa='EAU', name='Chippewa Valley Regional Airport', lat=44.8658, lon=-91.4843, alt=913, tz=-6, dst='A'),
#  Row(faa='ECA', name='Iosco County', lat=44.311, lon=-83.422, alt=606, tz=-5, dst='A'),
#  Row(faa='ECG', name='Elizabeth City Cgas Rgnl', lat=36.260581, lon=-76.174572, alt=12, tz=-5, dst='A'),
#  Row(faa='ECP', name='Panama City-NW Florida Bea.', lat=30.3417, lon=-85.7973, alt=69, tz=-6, dst='A'),
#  Row(faa='EDF', name='Elmendorf Afb', lat=61.250986, lon=-149.806503, alt=212, tz=-9, dst='A'),
#  Row(faa='EDW', name='Edwards Afb', lat=34.905417, lon=-117.883739, alt=2302, tz=-8, dst='A'),
#  Row(faa='EEK', name='Eek Airport', lat=60.213611, lon=-162.043889, alt=15, tz=-9, dst='A'),
#  Row(faa='EEN', name='Dillant Hopkins Airport', lat=72.270833, lon=42.898333, alt=149, tz=-5, dst='A'),
#  Row(faa='EET', name='Shelby County Airport', lat=33.1777778, lon=-86.7832222, alt=586, tz=-6, dst='A'),
#  Row(faa='EFD', name='Ellington Fld', lat=29.607333, lon=-95.15875, alt=32, tz=-6, dst='A'),
#  Row(faa='EGA', name='Eagle County Airport', lat=39.6427611, lon=-106.9159347, alt=6548, tz=-7, dst='U'),
#  Row(faa='EGE', name='Eagle Co Rgnl', lat=39.642556, lon=-106.917694, alt=6540, tz=-7, dst='A'),
#  Row(faa='EGT', name='Wellington Municipal', lat=37.39411, lon=-97.423225, alt=1277, tz=-4, dst='A'),
#  Row(faa='EGV', name='Eagle River', lat=45.932333, lon=-89.268283, alt=1642, tz=-6, dst='A'),
#  Row(faa='EGX', name='Egegik Airport', lat=58.185556, lon=-157.375556, alt=92, tz=-9, dst='A'),
#  Row(faa='EHM', name='Cape Newenham Lrrs', lat=58.646428, lon=-162.062778, alt=541, tz=-9, dst='A'),
#  Row(faa='EIL', name='Eielson Afb', lat=64.665667, lon=-147.1015, alt=548, tz=-9, dst='A'),
#  Row(faa='EKI', name='Elkhart Municipal', lat=41.719444, lon=-86.003333, alt=778, tz=-5, dst='A'),
#  Row(faa='EKN', name='Elkins Randolph Co Jennings Randolph', lat=38.889444, lon=-79.857139, alt=1987, tz=-5, dst='A'),
#  Row(faa='EKO', name='Elko Regional Airport', lat=40.8249, lon=-115.792, alt=5140, tz=-8, dst='A'),
#  Row(faa='ELD', name='South Arkansas Rgnl At Goodwin Fld', lat=33.220972, lon=-92.813278, alt=277, tz=-6, dst='A'),
#  Row(faa='ELI', name='Elim Airport', lat=64.615, lon=-162.270556, alt=162, tz=-9, dst='A'),
#  Row(faa='ELM', name='Elmira Corning Rgnl', lat=42.159889, lon=-76.891611, alt=954, tz=-5, dst='A'),
#  Row(faa='ELP', name='El Paso Intl', lat=31.80725, lon=-106.377583, alt=3958, tz=-7, dst='A'),
#  Row(faa='ELV', name='Elfin Cove Seaplane Base', lat=58.195278, lon=-136.3475, alt=0, tz=-9, dst='A'),
#  Row(faa='ELY', name='Ely Airport', lat=39.299722, lon=-114.841944, alt=6259, tz=-8, dst='A'),
#  Row(faa='EMK', name='Emmonak Airport', lat=62.786111, lon=-164.490833, alt=13, tz=-9, dst='A'),
#  Row(faa='EMP', name='Emporia Municipal Airport', lat=38.3321, lon=-96.1912, alt=1208, tz=-6, dst='A'),
#  Row(faa='ENA', name='Kenai Muni', lat=60.573111, lon=-151.245, alt=99, tz=-9, dst='A'),
#  Row(faa='END', name='Vance Afb', lat=36.339167, lon=-97.9165, alt=1307, tz=-6, dst='A'),
#  Row(faa='ENV', name='Wendover', lat=40.718694, lon=-114.030889, alt=4237, tz=-7, dst='A'),
#  Row(faa='ENW', name='Kenosha Regional Airport', lat=42.5956944, lon=-87.9278056, alt=742, tz=-6, dst='A'),
#  Row(faa='EOK', name='Keokuk Municipal Airport', lat=40.4599078, lon=-91.4285011, alt=671, tz=-6, dst='A'),
#  Row(faa='EPM', name='Eastport Municipal Airport', lat=44.9101111, lon=-67.0126944, alt=45, tz=-5, dst='A'),
#  Row(faa='EQY', name='Monroe Reqional Airport', lat=35.01833, lon=-80.62001, alt=679, tz=-5, dst='A'),
#  Row(faa='ERI', name='Erie Intl Tom Ridge Fld', lat=42.082022, lon=-80.176217, alt=733, tz=-5, dst='A'),
#  Row(faa='ERV', name='Kerrville Municipal Airport', lat=29.9766667, lon=-99.0854722, alt=1617, tz=-6, dst='A'),
#  Row(faa='ERY', name='Luce County Airport', lat=46.311199, lon=-85.457298, alt=869, tz=-5, dst='A'),
#  Row(faa='ESC', name='Delta County Airport', lat=45.722778, lon=-87.093611, alt=609, tz=-5, dst='A'),
#  Row(faa='ESD', name='Orcas Island Airport', lat=48.708056, lon=-122.910556, alt=31, tz=-8, dst='A'),
#  Row(faa='ESF', name='Esler Rgnl', lat=31.394903, lon=-92.295772, alt=112, tz=-6, dst='A'),
#  Row(faa='ESN', name='Easton-Newnam Field Airport', lat=38.8041667, lon=-76.069, alt=72, tz=-5, dst='A'),
#  Row(faa='EUG', name='Mahlon Sweet Fld', lat=44.124583, lon=-123.211972, alt=374, tz=-8, dst='A'),
#  Row(faa='EVV', name='Evansville Regional', lat=38.036997, lon=-87.532364, alt=418, tz=-6, dst='A'),
#  Row(faa='EWB', name='New Bedford Regional Airport', lat=41.6761, lon=-70.9569, alt=80, tz=-5, dst='A'),
#  Row(faa='EWN', name='Craven Co Rgnl', lat=35.072972, lon=-77.042944, alt=18, tz=-5, dst='A'),
#  Row(faa='EWR', name='Newark Liberty Intl', lat=40.6925, lon=-74.168667, alt=18, tz=-5, dst='A'),
#  Row(faa='EXI', name='Excursion Inlet Seaplane Base', lat=58.420556, lon=-135.449167, alt=0, tz=-9, dst='A'),
#  Row(faa='EYW', name='Key West Intl', lat=24.556111, lon=-81.759556, alt=3, tz=-5, dst='A'),
#  Row(faa='F57', name='Seaplane Base', lat=28.0575, lon=-81.7628056, alt=140, tz=-7, dst='A'),
#  Row(faa='FAF', name='Felker Aaf', lat=37.1325, lon=-76.608841, alt=12, tz=-5, dst='A'),
#  Row(faa='FAI', name='Fairbanks Intl', lat=64.815114, lon=-147.856267, alt=434, tz=-9, dst='A'),
#  Row(faa='FAR', name='Hector International Airport', lat=46.92065, lon=-96.8157639, alt=902, tz=-6, dst='A'),
#  Row(faa='FAT', name='Fresno Yosemite Intl', lat=36.776194, lon=-119.71814, alt=336, tz=-8, dst='A'),
#  Row(faa='FAY', name='Fayetteville Regional Grannis Field', lat=34.9912, lon=-78.8803, alt=189, tz=-5, dst='A'),
#  Row(faa='FBG', name='Fredericksburg Amtrak Station', lat=38.298416, lon=-77.456875, alt=130, tz=-5, dst='A'),
#  Row(faa='FBK', name='Ladd Aaf', lat=64.8375, lon=-147.614444, alt=454, tz=-9, dst='A'),
#  Row(faa='FBS', name='Friday Harbor Seaplane Base', lat=48.537222, lon=-123.009722, alt=0, tz=-8, dst='A'),
#  Row(faa='FCA', name='Glacier Park Intl', lat=48.310472, lon=-114.256, alt=2977, tz=-7, dst='A'),
#  Row(faa='FCS', name='Butts Aaf', lat=38.678394, lon=-104.756581, alt=5838, tz=-7, dst='A'),
#  Row(faa='FDY', name='Findlay Airport', lat=41.0120278, lon=-83.6686111, alt=819, tz=-5, dst='U'),
#  Row(faa='FFA', name='First Flight Airport', lat=36.02, lon=-75.67, alt=13, tz=-4, dst='A'),
#  Row(faa='FFC', name='Atlanta Regional Airport - Falcon Field', lat=33.35725, lon=-84.5718333, alt=808, tz=-4, dst='A'),
#  Row(faa='FFO', name='Wright Patterson Afb', lat=39.826111, lon=-84.048332, alt=823, tz=-5, dst='A'),
#  Row(faa='FFT', name='Capital City Airport', lat=38.1819722, lon=-84.9061389, alt=812, tz=-4, dst='A'),
#  Row(faa='FFZ', name='Mesa Falcon Field', lat=33.4608001708984, lon=-111.727996826172, alt=1394, tz=-7, dst='A'),
#  Row(faa='FHU', name='Sierra Vista Muni Libby Aaf', lat=31.588472, lon=-110.344389, alt=4719, tz=-7, dst='A'),
#  Row(faa='FIT', name='Fitchburg Municipal Airport', lat=42.5541111, lon=-71.7589722, alt=348, tz=-4, dst='A'),
#  Row(faa='FKL', name='Franklin', lat=41.377874, lon=-79.860362, alt=1540, tz=-5, dst='A'),
#  Row(faa='FLD', name='Fond Du Lac County Airport', lat=43.7711667, lon=-88.4884167, alt=808, tz=-6, dst='A'),
#  Row(faa='FLG', name='Flagstaff Pulliam Airport', lat=35.140318, lon=-111.6692392, alt=7015, tz=-7, dst='N'),
#  Row(faa='FLL', name='Fort Lauderdale Hollywood Intl', lat=26.072583, lon=-80.15275, alt=9, tz=-5, dst='A'),
#  Row(faa='FLO', name='Florence Rgnl', lat=34.185361, lon=-79.723889, alt=146, tz=-5, dst='A'),
#  Row(faa='FLV', name='Sherman Aaf', lat=39.368332, lon=-94.914686, alt=772, tz=-6, dst='A'),
#  Row(faa='FME', name='Tipton', lat=39.085386, lon=-76.759414, alt=150, tz=-5, dst='A'),
#  Row(faa='FMH', name='Otis Angb', lat=41.658439, lon=-70.521417, alt=131, tz=-5, dst='A'),
#  Row(faa='FMN', name='Four Corners Rgnl', lat=36.74125, lon=-108.229944, alt=5506, tz=-7, dst='A'),
#  Row(faa='FMY', name='Page Fld', lat=26.586611, lon=-81.86325, alt=17, tz=-5, dst='A'),
# ...
#  Row(faa='MKE', name='General Mitchell Intl', lat=42.947222, lon=-87.896583, alt=723, tz=-6, dst='A'),
#  Row(faa='MKG', name='Muskegon County Airport', lat=43.1695, lon=-86.2382, alt=628, tz=-5, dst='A'),
#  Row(faa='MKK', name='Molokai', lat=21.152886, lon=-157.096256, alt=454, tz=-10, dst='N'),
#  Row(faa='MKL', name='Mc Kellar Sipes Rgnl', lat=35.599889, lon=-88.915611, alt=434, tz=-6, dst='A'),
#  Row(faa='MKO', name='Davis Fld', lat=35.656489, lon=-95.366656, alt=612, tz=-6, dst='A'),
#  Row(faa='MLB', name='Melbourne Intl', lat=28.102753, lon=-80.645258, alt=33, tz=-5, dst='A'),
#  Row(faa='MLC', name='Mc Alester Rgnl', lat=34.882403, lon=-95.783463, alt=770, tz=-6, dst='A'),
#  Row(faa='MLD', name='Malad City', lat=42.17, lon=-112.289, alt=4503, tz=-7, dst='A'),
#  Row(faa='MLI', name='Quad City Intl', lat=41.448528, lon=-90.507539, alt=590, tz=-6, dst='A'),
#  Row(faa='MLJ', name='Baldwin County Airport', lat=33.154225, lon=-83.2414139, alt=385, tz=-4, dst='A'),
#  Row(faa='MLL', name='Marshall Don Hunter Sr. Airport', lat=61.8646418, lon=-162.026111, alt=103, tz=-9, dst='A'),
#  Row(faa='MLS', name='Frank Wiley Field', lat=46.428, lon=-105.886, alt=2630, tz=-7, dst='A'),
#  Row(faa='MLT', name='Millinocket Muni', lat=45.647836, lon=-68.685561, alt=408, tz=-5, dst='A'),
#  Row(faa='MLU', name='Monroe Rgnl', lat=32.510864, lon=-92.037689, alt=79, tz=-6, dst='A'),
#  Row(faa='MLY', name='Manley Hot Springs Airport', lat=64.9975, lon=-150.644167, alt=270, tz=-9, dst='A'),
#  Row(faa='MMH', name='Mammoth Yosemite Airport', lat=37.624049, lon=-118.837772, alt=7128, tz=-8, dst='A'),
#  Row(faa='MMI', name='McMinn Co', lat=35.39919, lon=-84.56177, alt=874, tz=-5, dst='N'),
#  Row(faa='MMU', name='Morristown Municipal Airport', lat=40.79935, lon=-74.4148747, alt=187, tz=-5, dst='A'),
#  Row(faa='MMV', name='Mc Minnville Muni', lat=45.194444, lon=-123.135944, alt=163, tz=-8, dst='A'),
#  Row(faa='MNM', name='Menominee Marinette Twin Co', lat=45.12665, lon=-87.638443, alt=625, tz=-5, dst='A'),
#  Row(faa='MNT', name='Minto Airport', lat=65.143611, lon=-149.37, alt=460, tz=-9, dst='A'),
#  Row(faa='MOB', name='Mobile Rgnl', lat=30.691231, lon=-88.242814, alt=219, tz=-6, dst='A'),
#  Row(faa='MOD', name='Modesto City Co Harry Sham', lat=37.625817, lon=-120.954422, alt=97, tz=-8, dst='A'),
#  Row(faa='MOT', name='Minot Intl', lat=48.259378, lon=-101.280333, alt=1716, tz=-6, dst='A'),
#  Row(faa='MOU', name='Mountain Village Airport', lat=62.0954, lon=-163.682, alt=337, tz=-9, dst='A'),
#  Row(faa='MPB', name='Miami Seaplane Base', lat=25.7783, lon=-80.1703, alt=0, tz=-5, dst='A'),
#  Row(faa='MPI', name='MariposaYosemite', lat=37.3039, lon=-120.0222, alt=2454, tz=-8, dst='A'),
#  Row(faa='MPV', name='Edward F Knapp State', lat=44.203503, lon=-72.562328, alt=1165, tz=-5, dst='A'),
#  Row(faa='MQB', name='Macomb Municipal Airport', lat=40.5200833, lon=-90.6523889, alt=707, tz=-6, dst='U'),
#  Row(faa='MQT', name='Sawyer International Airport', lat=46.353611, lon=-87.395278, alt=1221, tz=-5, dst='A'),
#  Row(faa='MRB', name='Eastern WV Regional Airport', lat=39.2407, lon=-77.591, alt=554, tz=-5, dst='A'),
#  Row(faa='MRI', name='Merrill Fld', lat=61.213544, lon=-149.844447, alt=137, tz=-9, dst='A'),
#  Row(faa='MRK', name='Marco Islands', lat=25.9950278, lon=-81.6725278, alt=5, tz=-5, dst='A'),
#  Row(faa='MRN', name='Foothills Regional Airport', lat=35.8202336, lon=-81.6115119, alt=1270, tz=-4, dst='A'),
#  Row(faa='MRY', name='Monterey Peninsula', lat=36.587, lon=-121.842944, alt=257, tz=-8, dst='A'),
#  Row(faa='MSL', name='Northwest Alabama Regional Airport', lat=34.7453, lon=-87.6102, alt=550, tz=-6, dst='A'),
#  Row(faa='MSN', name='Dane Co Rgnl Truax Fld', lat=43.139858, lon=-89.337514, alt=887, tz=-6, dst='A'),
#  Row(faa='MSO', name='Missoula Intl', lat=46.916306, lon=-114.090556, alt=3205, tz=-7, dst='A'),
#  Row(faa='MSP', name='Minneapolis St Paul Intl', lat=44.881956, lon=-93.221767, alt=841, tz=-6, dst='A'),
#  Row(faa='MSS', name='Massena Intl Richards Fld', lat=44.935833, lon=-74.845547, alt=215, tz=-5, dst='A'),
#  Row(faa='MSY', name='Louis Armstrong New Orleans Intl', lat=29.993389, lon=-90.258028, alt=4, tz=-6, dst='A'),
#  Row(faa='MTC', name='Selfridge Angb', lat=42.608333, lon=-82.8355, alt=580, tz=-5, dst='A'),
#  Row(faa='MTH', name='Florida Keys Marathon Airport', lat=24.726111, lon=-81.051389, alt=7, tz=-5, dst='A'),
#  Row(faa='MTJ', name='Montrose Regional Airport', lat=38.509794, lon=-107.894242, alt=5759, tz=-7, dst='A'),
#  Row(faa='MTM', name='Metlakatla Seaplane Base', lat=55.131111, lon=-131.578056, alt=0, tz=-9, dst='A'),
#  Row(faa='MUE', name='Waimea Kohala', lat=20.001328, lon=-155.668108, alt=2671, tz=-10, dst='A'),
#  Row(faa='MUI', name='Muir Aaf', lat=40.434811, lon=-76.569411, alt=489, tz=-5, dst='A'),
#  Row(faa='MUO', name='Mountain Home Afb', lat=43.043603, lon=-115.872431, alt=2996, tz=-7, dst='A'),
#  Row(faa='MVL', name='Morrisville Stowe State Airport', lat=44.535, lon=-72.614, alt=732, tz=-5, dst='A'),
#  Row(faa='MVY', name="Martha\\\\'s Vineyard", lat=41.391667, lon=-70.615278, alt=67, tz=-5, dst='A'),
#  Row(faa='MWA', name='Williamson Country Regional Airport', lat=37.7549569, lon=-89.0110936, alt=472, tz=-5, dst='A'),
#  Row(faa='MWC', name='Lawrence J Timmerman Airport', lat=43.1103889, lon=-88.0344167, alt=745, tz=-6, dst='A'),
#  Row(faa='MWH', name='Grant Co Intl', lat=47.207708, lon=-119.32019, alt=1185, tz=-8, dst='A'),
#  Row(faa='MWL', name='Mineral Wells', lat=32.781606, lon=-98.060175, alt=974, tz=-6, dst='A'),
#  Row(faa='MWM', name='Windom Municipal Airport', lat=43.9134017, lon=-95.1094083, alt=1410, tz=-6, dst='A'),
#  Row(faa='MXF', name='Maxwell Afb', lat=32.382944, lon=-86.365778, alt=171, tz=-6, dst='A'),
#  Row(faa='MXY', name='McCarthy Airport', lat=61.4370608, lon=-142.90307372, alt=1531, tz=-8, dst='U'),
#  Row(faa='MYF', name='Montgomery Field', lat=32.4759, lon=117.759, alt=17, tz=-8, dst='A'),
#  Row(faa='MYL', name='McCall Municipal Airport', lat=44.889722, lon=-116.101389, alt=5021, tz=-7, dst='A'),
#  Row(faa='MYR', name='Myrtle Beach Intl', lat=33.67975, lon=-78.928333, alt=25, tz=-5, dst='A'),
#  Row(faa='MYU', name='Mekoryuk Airport', lat=60.3714, lon=-166.271, alt=48, tz=-9, dst='A'),
#  Row(faa='MYV', name='Yuba County Airport', lat=39.0553, lon=-121.3411, alt=62, tz=-8, dst='A'),
#  Row(faa='MZJ', name='Pinal Airpark', lat=32.509722, lon=-111.325278, alt=1893, tz=-7, dst='N'),
#  Row(faa='N53', name='Stroudsburg-Pocono Airport', lat=41.0358717, lon=-75.1606789, alt=480, tz=-5, dst='A'),
#  Row(faa='N69', name='Stormville Airport', lat=41.5769708, lon=-73.7323514, alt=358, tz=-5, dst='A'),
#  Row(faa='N87', name='Trenton-Robbinsville Airport', lat=40.2139444, lon=-74.6017778, alt=118, tz=-5, dst='A'),
#  Row(faa='NBG', name='New Orleans Nas Jrb', lat=29.825333, lon=-90.035, alt=3, tz=-6, dst='A'),
#  Row(faa='NBU', name='Naval Air Station', lat=42.090556, lon=-87.8225, alt=653, tz=-6, dst='A'),
#  Row(faa='NCN', name='Chenega Bay Airport', lat=60.077222, lon=-147.991944, alt=72, tz=-9, dst='A'),
#  Row(faa='NEL', name='Lakehurst Naes', lat=40.033333, lon=-74.353333, alt=103, tz=-5, dst='A'),
#  Row(faa='NFL', name='Fallon Nas', lat=39.416584, lon=-118.70098, alt=3934, tz=-8, dst='A'),
#  Row(faa='NGF', name='Kaneohe Bay Mcaf', lat=21.450453, lon=-157.768, alt=24, tz=-10, dst='A'),
#  Row(faa='NGP', name='Corpus Christi NAS', lat=27.692701, lon=-97.290376, alt=18, tz=-6, dst='A'),
#  Row(faa='NGU', name='Norfolk Ns', lat=36.937644, lon=-76.289289, alt=15, tz=-5, dst='A'),
#  Row(faa='NGZ', name='NAS Alameda', lat=37.7861, lon=-122.3186, alt=10, tz=-9, dst='U'),
#  Row(faa='NHK', name='Patuxent River Nas', lat=38.285981, lon=-76.411781, alt=39, tz=-5, dst='A'),
#  Row(faa='NIB', name='Nikolai Airport', lat=63.010833, lon=-154.383889, alt=427, tz=-9, dst='A'),
#  Row(faa='NID', name='China Lake Naws', lat=35.685422, lon=-117.692039, alt=2283, tz=-8, dst='A'),
#  Row(faa='NIP', name='Jacksonville Nas', lat=30.235834, lon=-81.680556, alt=22, tz=-5, dst='A'),
#  Row(faa='NJK', name='El Centro Naf', lat=32.829222, lon=-115.671667, alt=-42, tz=-8, dst='A'),
#  Row(faa='NKT', name='Cherry Point Mcas', lat=34.900872, lon=-76.880733, alt=29, tz=-5, dst='A'),
#  Row(faa='NKX', name='Miramar Mcas', lat=32.867694, lon=-117.14175, alt=478, tz=-8, dst='A'),
#  Row(faa='NLC', name='Lemoore Nas', lat=36.333012, lon=-119.95208, alt=234, tz=-8, dst='A'),
#  Row(faa='NLG', name='Nelson Lagoon', lat=56.0075, lon=-161.160278, alt=14, tz=-9, dst='A'),
#  Row(faa='NME', name='Nightmute Airport', lat=60.471111, lon=-164.700833, alt=4, tz=-10, dst='A'),
#  Row(faa='NMM', name='Meridian Nas', lat=32.552083, lon=-88.555557, alt=317, tz=-6, dst='A'),
#  Row(faa='NNL', name='Nondalton Airport', lat=59.966944, lon=-154.851667, alt=262, tz=-9, dst='A'),
#  Row(faa='NOW', name='Port Angeles Cgas', lat=48.141481, lon=-123.414075, alt=13, tz=-8, dst='A'),
#  Row(faa='NPA', name='Pensacola Nas', lat=30.352656, lon=-87.318647, alt=28, tz=-6, dst='A'),
#  Row(faa='NPZ', name='Porter County Municipal Airport', lat=41.4539722, lon=-87.0070833, alt=770, tz=-6, dst='A'),
#  Row(faa='NQA', name='Millington Rgnl Jetport', lat=35.356667, lon=-89.870278, alt=320, tz=-6, dst='A'),
#  Row(faa='NQI', name='Kingsville Nas', lat=27.507223, lon=-97.809723, alt=50, tz=-6, dst='A'),
#  Row(faa='NQX', name='Key West Nas', lat=24.575834, lon=-81.688889, alt=6, tz=-5, dst='A'),
#  Row(faa='NSE', name='Whiting Fld Nas North', lat=30.724167, lon=-87.021944, alt=199, tz=-6, dst='A'),
#  Row(faa='NTD', name='Point Mugu Nas', lat=34.120285, lon=-119.12094, alt=13, tz=-8, dst='A'),
#  Row(faa='NTU', name='Oceana Nas', lat=36.820703, lon=-76.033542, alt=22, tz=-5, dst='A'),
#  Row(faa='NUI', name='Nuiqsut Airport', lat=70.21, lon=-151.005556, alt=38, tz=-9, dst='A'),
#  Row(faa='NUL', name='Nulato Airport', lat=64.729444, lon=-158.074167, alt=399, tz=-9, dst='A'),
#  Row(faa='NUP', name='Nunapitchuk Airport', lat=60.905833, lon=-162.439167, alt=12, tz=-9, dst='A'),
#  Row(faa='NUQ', name='Moffett Federal Afld', lat=37.416142, lon=-122.049139, alt=32, tz=-8, dst='A'),
#  Row(faa='NUW', name='Whidbey Island Nas', lat=48.351803, lon=-122.655906, alt=47, tz=-8, dst='A'),
#  Row(faa='NXP', name='Twentynine Palms Eaf', lat=34.296161, lon=-116.162203, alt=2051, tz=-8, dst='A'),
#  Row(faa='NXX', name='Willow Grove Nas Jrb', lat=40.199833, lon=-75.148167, alt=358, tz=-5, dst='A'),
#  Row(faa='NY9', name='Long Lake', lat=43.9750617, lon=-74.42044, alt=1629, tz=5, dst='A'),
#  Row(faa='NYC', name='All Airports', lat=40.714167, lon=-74.005833, alt=31, tz=-5, dst='A'),
#  Row(faa='NYG', name='Quantico Mcaf', lat=38.501683, lon=-77.305333, alt=11, tz=-5, dst='A'),
#  Row(faa='NZC', name='Cecil Field', lat=30.2187, lon=-81.8767, alt=81, tz=-5, dst='A'),
#  Row(faa='NZJ', name='El Toro', lat=33.676132, lon=-117.731164, alt=383, tz=-8, dst='A'),
#  Row(faa='NZY', name='North Island Nas', lat=32.699219, lon=-117.21531, alt=26, tz=-8, dst='A'),
#  Row(faa='O03', name='Morgantown Airport', lat=40.1570414, lon=-75.8704892, alt=600, tz=-5, dst='A'),
#  Row(faa='O27', name='Oakdale Airport', lat=37.7563333, lon=-120.8001944, alt=237, tz=-8, dst='A'),
#  Row(faa='OAJ', name='Albert J Ellis', lat=34.829164, lon=-77.612139, alt=94, tz=-5, dst='A'),
#  Row(faa='OAK', name='Metropolitan Oakland Intl', lat=37.721278, lon=-122.220722, alt=9, tz=-8, dst='A'),
#  Row(faa='OAR', name='Marina Muni', lat=36.681878, lon=-121.762347, alt=134, tz=-8, dst='A'),
#  Row(faa='OBE', name='County', lat=27.265833, lon=-80.851111, alt=34, tz=-5, dst='A'),
#  Row(faa='OBU', name='Kobuk Airport', lat=66.912222, lon=-156.897222, alt=137, tz=-9, dst='A'),
#  Row(faa='OCA', name='Key Largo', lat=25.325393, lon=-80.274775, alt=8, tz=-5, dst='A'),
#  Row(faa='OCF', name='International Airport', lat=29.1725, lon=-82.224167, alt=89, tz=-5, dst='A'),
#  Row(faa='OEB', name='Branch County Memorial Airport', lat=41.9335691, lon=-85.0522935, alt=959, tz=-5, dst='A'),
#  Row(faa='OFF', name='Offutt Afb', lat=41.118332, lon=-95.912511, alt=1052, tz=-6, dst='A'),
#  Row(faa='OGG', name='Kahului', lat=20.89865, lon=-156.430458, alt=54, tz=-10, dst='N'),
#  Row(faa='OGS', name='Ogdensburg Intl', lat=44.681854, lon=-75.4655, alt=297, tz=-5, dst='A'),
#  Row(faa='OKC', name='Will Rogers World', lat=35.393089, lon=-97.600733, alt=1295, tz=-6, dst='A'),
#  Row(faa='OLF', name='LM Clayton Airport', lat=48.094444, lon=-105.575, alt=1986, tz=-7, dst='A'),
#  Row(faa='OLH', name='Old Harbor Airport', lat=57.218056, lon=-153.269722, alt=55, tz=-9, dst='A'),
#  Row(faa='OLM', name='Olympia Regional Airpor', lat=46.9694044, lon=-122.9025447, alt=209, tz=-7, dst='A'),
#  Row(faa='OLS', name='Nogales Intl', lat=31.417722, lon=-110.84789, alt=3955, tz=-7, dst='A'),
#  Row(faa='OLV', name='Olive Branch Muni', lat=34.876944, lon=-89.783333, alt=350, tz=-6, dst='A'),
#  Row(faa='OMA', name='Eppley Afld', lat=41.303167, lon=-95.894069, alt=984, tz=-6, dst='A'),
#  Row(faa='OME', name='Nome', lat=64.512203, lon=-165.445247, alt=37, tz=-9, dst='A'),
#  Row(faa='OMN', name='Ormond Beach municipal Airport', lat=29.1804, lon=-81.06497, alt=28, tz=-5, dst='A'),
#  Row(faa='ONH', name='Oneonta Municipal Airport', lat=42.524722, lon=-75.064444, alt=1763, tz=-5, dst='A'),
#  Row(faa='ONP', name='Newport Municipal Airport', lat=44.580361, lon=-124.057917, alt=160, tz=8, dst='A'),
#  Row(faa='ONT', name='Ontario Intl', lat=34.056, lon=-117.601194, alt=944, tz=-8, dst='A'),
#  Row(faa='OOK', name='Toksook Bay Airport', lat=60.541389, lon=-165.087222, alt=59, tz=-10, dst='A'),
#  Row(faa='OPF', name='Opa Locka', lat=25.907, lon=-80.278389, alt=8, tz=-5, dst='A'),
#  Row(faa='OQU', name='Quonset State Airport', lat=41.5971389, lon=-71.4121389, alt=18, tz=-4, dst='A'),
#  Row(faa='ORD', name='Chicago Ohare Intl', lat=41.978603, lon=-87.904842, alt=668, tz=-6, dst='A'),
#  Row(faa='ORF', name='Norfolk Intl', lat=36.894611, lon=-76.201222, alt=26, tz=-5, dst='A'),
#  Row(faa='ORH', name='Worcester Regional Airport', lat=42.2673, lon=-71.8757, alt=1009, tz=-5, dst='A'),
#  Row(faa='ORI', name='Port Lions Airport', lat=57.885278, lon=-152.846111, alt=52, tz=-9, dst='A'),
#  Row(faa='ORL', name='Executive', lat=28.545464, lon=-81.332936, alt=113, tz=-5, dst='A'),
#  Row(faa='ORT', name='Northway', lat=62.961334, lon=-141.929136, alt=1716, tz=-9, dst='A'),
#  Row(faa='ORV', name='Robert Curtis Memorial Airport', lat=66.8175, lon=-161.022222, alt=55, tz=-9, dst='A'),
#  Row(faa='OSC', name='Oscoda Wurtsmith', lat=44.451558, lon=-83.394053, alt=634, tz=-5, dst='A'),
#  Row(faa='OSH', name='Wittman Regional Airport', lat=44.024983, lon=-88.551336, alt=790, tz=-5, dst='A'),
#  Row(faa='OSU', name='Ohio State University Airport', lat=40.0798, lon=-83.073, alt=905, tz=-5, dst='U'),
#  Row(faa='OTH', name='Southwest Oregon Regional Airport', lat=43.4171, lon=-124.246, alt=17, tz=-8, dst='A'),
#  Row(faa='OTS', name='Anacortes Airport', lat=48.498889, lon=-122.6625, alt=241, tz=-8, dst='A'),
#  Row(faa='OTZ', name='Ralph Wien Mem', lat=66.884678, lon=-162.59855, alt=11, tz=-9, dst='A'),
#  Row(faa='OWB', name='Owensboro Daviess County Airport', lat=37.7401, lon=-87.1668, alt=406, tz=-6, dst='A'),
#  Row(faa='OWD', name='Norwood Memorial Airport', lat=42.1905278, lon=-71.1729444, alt=49, tz=-5, dst='A'),
#  Row(faa='OXC', name='Waterbury-Oxford Airport', lat=41.4785556, lon=-73.13525, alt=726, tz=-4, dst='A'),
#  Row(faa='OXD', name='Miami University Airport', lat=39.5022607, lon=-84.7843814, alt=1040, tz=-5, dst='U'),
#  Row(faa='OXR', name='Oxnard - Ventura County', lat=34.200833, lon=-119.207222, alt=15, tz=-8, dst='A'),
#  Row(faa='OZA', name='Ozona Muni', lat=30.735281, lon=-101.202972, alt=2381, tz=-6, dst='A'),
#  Row(faa='P08', name='Coolidge Municipal Airport', lat=32.9359016418457, lon=-111.427001953125, alt=1574, tz=-7, dst='A'),
#  Row(faa='P52', name='Cottonwood Airport', lat=34.7299995422363, lon=-112.035003662109, alt=3550, tz=-7, dst='A'),
#  Row(faa='PAE', name='Snohomish Co', lat=47.906342, lon=-122.281564, alt=606, tz=-8, dst='A'),
#  Row(faa='PAH', name='Barkley Regional Airport', lat=37.0602875, lon=-88.7729583, alt=410, tz=-6, dst='A'),
#  ...]

# %%
# 2.1.2
type(airports_df.head(4))               # List
# 2.1.3
type(airports_df.head(4)[0])            # Row
# Out:
# list
# pyspark.sql.types.Row

# %%
# 2.2 Better display in columnar format

airports_df.show(5)                     # Tabular format
airports_df.show(5, False)              # Tabular format with extended columns
# Out:
# +---+--------------------+----------+-----------+----+---+---+
# |faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
# |06C| Schaumburg Regional|41.9893408|-88.1012428| 801| -6|  A|
# |06N|     Randall Airport| 41.431912|-74.3915611| 523| -5|  A|
# |09J|Jekyll Island Air...|31.0744722|-81.4277778|  11| -4|  A|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 5 rows
#
# +---+-----------------------------+----------+-----------+----+---+---+
# |faa|name                         |lat       |lon        |alt |tz |dst|
# +---+-----------------------------+----------+-----------+----+---+---+
# |04G|Lansdowne Airport            |41.1304722|-80.6195833|1044|-5 |A  |
# |06A|Moton Field Municipal Airport|32.4605722|-85.6800278|264 |-5 |A  |
# |06C|Schaumburg Regional          |41.9893408|-88.1012428|801 |-6 |A  |
# |06N|Randall Airport              |41.431912 |-74.3915611|523 |-5 |A  |
# |09J|Jekyll Island Airport        |31.0744722|-81.4277778|11  |-4 |A  |
# +---+-----------------------------+----------+-----------+----+---+---+
# only showing top 5 rows

# %%
# 3.0 Have a look at the dataframe schema,
#     i.e. the structure of the DataFrame

airports_df.printSchema()
airports_df.dtypes
# Out:
# root
#  |-- faa: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- alt: integer (nullable = true)
#  |-- tz: integer (nullable = true)
#  |-- dst: string (nullable = true)
# [('faa', 'string'),
#  ('name', 'string'),
#  ('lat', 'double'),
#  ('lon', 'double'),
#  ('alt', 'int'),
#  ('tz', 'int'),
#  ('dst', 'string')]

# %%
# 3.1 Column names
airports_df.columns
# Out:
# ['faa', 'name', 'lat', 'lon', 'alt', 'tz', 'dst']

# %%
# 3.2 How many rows:
airports_df.count()          # 1397

# 3.3 How many columns?
len(airports_df.columns)     # 7
# Out:
# 1397
# 7

# %%
# 3.4 Full data summary
airports_df.describe().show()
# 3.4.1 Describe a particular column
airports_df.describe('dst').show(5)
# Out:
# +-------+------------------+--------------------+------------------+------------------+------------------+------------------+----+
# |summary|               faa|                name|               lat|               lon|               alt|                tz| dst|
# +-------+------------------+--------------------+------------------+------------------+------------------+------------------+----+
# |  count|              1397|                1397|              1397|              1397|              1397|              1397|1397|
# |   mean|             141.0|                null| 41.75029635989892|-103.6891285724532|1005.9169649248389|-6.420901932712956|null|
# | stddev|197.46392075515973|                null|10.549872185047212|30.125313702028542|1521.2701426664623|1.8244027290430729|null|
# |    min|               04G|Aberdeen Regional...|         19.721375|          -176.646|               -54|               -11|   A|
# |    max|               ZYP|Zamperini Field A...|         72.270833|         174.11362|              9078|                 8|   U|
# +-------+------------------+--------------------+------------------+------------------+------------------+------------------+----+
#
# +-------+----+
# |summary| dst|
# +-------+----+
# |  count|1397|
# |   mean|null|
# | stddev|null|
# |    min|   A|
# |    max|   U|
# +-------+----+

# %%
###### C. Using Verbs
#         Select, filter, groupby, distinct, count()
#         It is more like 'dplyr' syntax, only that instead
#         of %>%, we have dot (.) .


# 4 Selecting Single/Multiple Columns
#   This does now work:   airports_df['faa'].show(5)
#    Following also does not work. Limitations
#    come because data is divided into chunks in various
#    servers.

airports_df[:2, :].show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-ac9d4868a580> in <module>
#      11 #    servers.
#      12
# ---> 13 airports_df[:2, :].show()
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in __getitem__(self, item)
#    1282             return self.filter(item)
#    1283         elif isinstance(item, (list, tuple)):
# -> 1284             return self.select(*item)
#    1285         elif isinstance(item, int):
#    1286             jc = self._jdf.apply(self.columns[item])
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1318         [Row(name=u'Alice', age=12), Row(name=u'Bob', age=15)]
#    1319         """
# -> 1320         jdf = self._jdf.select(self._jcols(*cols))
#    1321         return DataFrame(jdf, self.sql_ctx)
#    1322
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in _jcols(self, *cols)
#    1114         if len(cols) == 1 and isinstance(cols[0], list):
#    1115             cols = cols[0]
# -> 1116         return self._jseq(cols, _to_java_column)
#    1117
#    1118     def _sort_cols(self, cols, kwargs):
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in _jseq(self, cols, converter)
#    1101     def _jseq(self, cols, converter=None):
#    1102         """Return a JVM Seq of Columns from a list of Column or names"""
# -> 1103         return _to_seq(self.sql_ctx._sc, cols, converter)
#    1104
#    1105     def _jmap(self, jm):
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/column.py in _to_seq(sc, cols, converter)
#      63     """
#      64     if converter:
# ---> 65         cols = [converter(c) for c in cols]
#      66     return sc._jvm.PythonUtils.toSeq(cols)
#      67
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/column.py in <listcomp>(.0)
#      63     """
#      64     if converter:
# ---> 65         cols = [converter(c) for c in cols]
#      66     return sc._jvm.PythonUtils.toSeq(cols)
#      67
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/column.py in _to_java_column(col)
#      51             "{0} of type {1}. "
#      52             "For column literals, use 'lit', 'array', 'struct' or 'create_map' "
# ---> 53             "function.".format(col, type(col)))
#      54     return jcol
#      55
#
# TypeError: Invalid argument, not a string or column: slice(None, 2, None) of type <class 'slice'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.

# %%
# 4.1
airports_df.select('faa').show(3)

#4.2 Both the following work:
airports_df.select('faa','dst').show(3)
airports_df.select(['faa','dst']).show(3)        # List of columns
# Out:
# +---+
# |faa|
# +---+
# |04G|
# |06A|
# |06C|
# +---+
# only showing top 3 rows
#
# +---+---+
# |faa|dst|
# +---+---+
# |04G|  A|
# |06A|  A|
# |06C|  A|
# +---+---+
# only showing top 3 rows
#
# +---+---+
# |faa|dst|
# +---+---+
# |04G|  A|
# |06A|  A|
# |06C|  A|
# +---+---+
# only showing top 3 rows

# %%
# 4.3 Selecting Distinct values in Multiple Columns

airports_df.select('dst','tz').show()                 # Many repeating records
airports_df.select('dst','tz').distinct().show()      # Unique records

airports_df.select('dst','tz').count()                # 1397
airports_df.select('dst','tz').distinct().count()     # 22
# Out:
# +---+---+
# |dst| tz|
# +---+---+
# |  A| -5|
# |  A| -5|
# |  A| -6|
# |  A| -5|
# |  A| -4|
# |  A| -4|
# |  A| -5|
# |  A| -5|
# |  U| -5|
# |  A| -8|
# |  A| -5|
# |  U| -6|
# |  A| -5|
# |  U| -4|
# |  A| -4|
# |  A| -5|
# |  A| -8|
# |  U| -6|
# |  A| -4|
# |  U| -5|
# +---+---+
# only showing top 20 rows
#
# +---+---+
# |dst| tz|
# +---+---+
# |  A|  7|
# |  A| -9|
# |  A| -4|
# |  U| -9|
# |  A|  8|
# |  A| -7|
# |  N| -7|
# |  N|-10|
# |  A| -8|
# |  U| -4|
# |  A|  5|
# |  A|-10|
# |  A| -5|
# |  U| -5|
# |  U| -8|
# |  N| -5|
# |  U|-10|
# |  A|  6|
# |  A|-11|
# |  A| -6|
# +---+---+
# only showing top 20 rows
# 1397
# 22

# %%
# 4.4 Like operator in where clause.
#        'where'  is an alias for 'filter' (see below)

airports_df.select('name'). \
            where("name like '%La%'").\
            show(3,False)
# Out:
# +-----------------------------+
# |name                         |
# +-----------------------------+
# |Lansdowne Airport            |
# |Finger Lakes Regional Airport|
# |Frazier Lake Airpark         |
# +-----------------------------+
# only showing top 3 rows

# %%
# 5. Filtering data
# http://spark.apache.org/docs/2.0.0/api/python/pyspark.sql.html#pyspark.sql.DataFrame.filter
#  We use the filter command to filter our DataFrame based
#  on the condition that tz must be equal to -5 and then
#  we are calculating how many records/rows are there in
#  the filtered output.
#  Syntax: filter(condition) 

# 5.1
airports_df.filter(airports_df.tz == -5) .show(3)
# 5.2
airports_df.filter(airports_df["tz"] == -5) .show(3)
# 5.3
airports_df.filter("tz == -5") .show(3)                          # Different syntax
# 5.4
from pyspark.sql.functions import col
airports_df.filter(col("tz") == -5) .show(3)
# Out:
# +---+--------------------+----------+-----------+----+---+---+
# |faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
# |06N|     Randall Airport| 41.431912|-74.3915611| 523| -5|  A|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 3 rows
#
# +---+--------------------+----------+-----------+----+---+---+
# |faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
# |06N|     Randall Airport| 41.431912|-74.3915611| 523| -5|  A|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 3 rows
#
# +---+--------------------+----------+-----------+----+---+---+
# |faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
# |06N|     Randall Airport| 41.431912|-74.3915611| 523| -5|  A|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 3 rows
#
# +---+--------------------+----------+-----------+----+---+---+
# |faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
# |06N|     Randall Airport| 41.431912|-74.3915611| 523| -5|  A|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 3 rows

# %%
# 5.5 Filter with regular expression:
airports_df.select('name'). \
            where(" name rlike  'pal$' " ). \
            show(3,truncate = False) 
# 5.6  where is an alias for filter  
airports_df.select('name'). \
            filter(" name rlike  'pal$' " ). \
            show(3,truncate = False) 
# 5.7    
airports_df.filter(" name rlike  'pal$' " ). \
            show(3,truncate = False)
# Out:
# +-------------------+
# |name               |
# +-------------------+
# |Mansfield Municipal|
# |Wadsworth Municipal|
# |Barnes Municipal   |
# +-------------------+
# only showing top 3 rows
#
# +-------------------+
# |name               |
# +-------------------+
# |Mansfield Municipal|
# |Wadsworth Municipal|
# |Barnes Municipal   |
# +-------------------+
# only showing top 3 rows
#
# +---+-------------------+----------+-----------+---+---+---+
# |faa|name               |lat       |lon        |alt|tz |dst|
# +---+-------------------+----------+-----------+---+---+---+
# |1B9|Mansfield Municipal|42.0001331|-71.1967714|122|-5 |A  |
# |3G3|Wadsworth Municipal|41.0031572|-81.7564401|974|-5 |A  |
# |BAF|Barnes Municipal   |42.1579472|-72.715875 |270|-4 |A  |
# +---+-------------------+----------+-----------+---+---+---+
# only showing top 3 rows

# %%
# 6. Combining verbs: select, filter and distinct
airports_df.select('dst', 'tz'). \
            filter(airports_df.tz == -5). \
            show(3)

airports_df.select('dst', 'tz'). \
            filter(airports_df.tz == -5). \
            distinct(). \
            show(3)
# Out:
# +---+---+
# |dst| tz|
# +---+---+
# |  A| -5|
# |  A| -5|
# |  A| -5|
# +---+---+
# only showing top 3 rows
#
# +---+---+
# |dst| tz|
# +---+---+
# |  A| -5|
# |  U| -5|
# |  N| -5|
# +---+---+

# %%
# 6.1 We can filter our data based on multiple conditions (AND or OR)
#     Logical Operators: & ==and,   | == or   ~ == not

airports_df.filter(                         \
                   (airports_df.tz == -5) & \
                   (airports_df.dst !="A")). \
                   show(3)
# Out:
# +---+--------------------+----------+-----------+----+---+---+
# |faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# |0P2|Shoestring Aviati...|39.7948244|-76.6471914|1000| -5|  U|
# |1OH|     Fortman Airport|40.5553253|-84.3866186| 885| -5|  U|
# |4I7|Putnam County Air...|39.6335556|-86.8138056| 842| -5|  U|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 3 rows

# %%
# 7. groupby. Can apply sum, min, max, count

airports_df.groupby('tz'). \
           count(). \
           show(3)

airports_df.groupby('tz'). \
            agg({'lat' : 'count'}). \
            show(3)
# Out:
# +---+-----+
# | tz|count|
# +---+-----+
# |-10|   26|
# |-11|    2|
# |  6|    1|
# +---+-----+
# only showing top 3 rows
#
# +---+----------+
# | tz|count(lat)|
# +---+----------+
# |-10|        26|
# |-11|         2|
# |  6|         1|
# +---+----------+
# only showing top 3 rows

# %%
"""
Unpacking operator in python (*) : 
Ref: https://codeyarns.com/2012/04/26/unpack-operator-in-python/ 

def fox(a,b):  
    return (a *b)  

m = [3,4]  
fox(m)    
fox(*m)   

"""

# %%
# 7.1 One can take the average of columns by passing
#       an unpacked list of column names.

grObject = airports_df.groupby('tz')

avg_cols = ['lat', 'lon']
grObject.avg(*avg_cols).show(3)
# Out:
# +---+-----------------+-------------------+
# | tz|         avg(lat)|           avg(lon)|
# +---+-----------------+-------------------+
# |-10|32.38998811538461|-146.58902384615382|
# |-11|       56.8728385|       -169.9410275|
# |  6|          29.5569|         -95.137497|
# +---+-----------------+-------------------+
# only showing top 3 rows

# %%
# 7.2 To call multiple aggregation functions at once, pass a dictionary.
#         The 'key' of dictionary becomes argument to 'value'.
#                             count(*)        avg(lat)      sum(lon)

grObject.agg({'*': 'count', 'lat': 'avg', 'lon':'sum'}).show(2)
# Out:
# +---+--------+-------------------+-----------------+
# | tz|count(1)|           sum(lon)|         avg(lat)|
# +---+--------+-------------------+-----------------+
# |-10|      26|-3811.3146199999996|32.38998811538461|
# |-11|       2|        -339.882055|       56.8728385|
# +---+--------+-------------------+-----------------+
# only showing top 2 rows

# %%
# 8. Create new columns in Spark using .withColumn() --mutate
#      New column: altInThousands . 
#      Product of two columns:  'alt' and  'lon' 

airports_df.withColumn('altInThousands', 
                       airports_df.alt*airports_df.lon
                      ).show(3)
# Out:
# +---+--------------------+----------+-----------+----+---+---+--------------+
# |faa|                name|       lat|        lon| alt| tz|dst|altInThousands|
# +---+--------------------+----------+-----------+----+---+---+--------------+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|-84166.8449652|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|-22619.5273392|
# |06C| Schaumburg Regional|41.9893408|-88.1012428| 801| -6|  A|-70569.0954828|
# +---+--------------------+----------+-----------+----+---+---+--------------+
# only showing top 3 rows

# %%
# 9. Save the new file with additional column in parquet form

xyz = airports_df.withColumn('altInThousands', airports_df.alt*airports_df.lon)
xyz.write.parquet("hdfs://localhost:9000/user/ashok/data_files/airports_extra.parquet")

# %%
# 9.1 Delete xyz from spark
import gc
del xyz
gc.collect()    # Delete all cache also
# Out:
# 746

# %%
# 9.2 Read the stored parquet file
df = spark.read.parquet("hdfs://localhost:9000/user/ashok/data_files/airports_extra.parquet")
df.show(3)
# Out:
# +---+--------------------+----------+-----------+----+---+---+--------------+
# |faa|                name|       lat|        lon| alt| tz|dst|altInThousands|
# +---+--------------------+----------+-----------+----+---+---+--------------+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|-84166.8449652|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|-22619.5273392|
# |06C| Schaumburg Regional|41.9893408|-88.1012428| 801| -6|  A|-70569.0954828|
# +---+--------------------+----------+-----------+----+---+---+--------------+
# only showing top 3 rows

# %%
# 9.3 Read 'weather.csv file into spark from hadoop

URL_of_file= "hdfs://localhost:9000/user/ashok/data_files/nycflights/"
weather_df = spark.read.csv(path = URL_of_file + "weather.csv",
                            inferSchema = True,
                            header = True
                           )
weather_df.show(3)
# Out:
# +------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |origin|year|month|day|hour| temp| dewp|humid|wind_dir|wind_speed|    wind_gust|precip|pressure|visib|          time_hour|
# +------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |   EWR|2013|    1|  1|   0|37.04|21.92|53.97|     230|  10.35702|11.9186514756|   0.0|  1013.9| 10.0|2013-01-01 05:30:00|
# |   EWR|2013|    1|  1|   1|37.04|21.92|53.97|     230|  13.80936|15.8915353008|   0.0|    1013| 10.0|2013-01-01 06:30:00|
# |   EWR|2013|    1|  1|   2|37.94|21.92|52.09|     230|  12.65858|14.5672406924|   0.0|  1012.6| 10.0|2013-01-01 07:30:00|
# +------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# only showing top 3 rows

# %%
# 10. Joins
# Refer: http://www.learnbymarketing.com/1100/pyspark-joins-by-example/
# For example, I can join the two titanic dataframes by the column PassengerId

# 10.1
airports_df.join(weather_df, airports_df.faa==weather_df.origin).show(3)
# 10.2
airports_df.join(weather_df, airports_df.faa==weather_df.origin, how = 'inner').show(3)
# 10.3
airports_df.join(weather_df, airports_df.faa==weather_df.origin, how = 'left').show(3)   # Could also use 'left_outer', 'right', 'full'
# Out:
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |faa|               name|    lat|       lon|alt| tz|dst|origin|year|month|day|hour| temp| dewp|humid|wind_dir|wind_speed|    wind_gust|precip|pressure|visib|          time_hour|
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   0|37.04|21.92|53.97|     230|  10.35702|11.9186514756|   0.0|  1013.9| 10.0|2013-01-01 05:30:00|
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   1|37.04|21.92|53.97|     230|  13.80936|15.8915353008|   0.0|    1013| 10.0|2013-01-01 06:30:00|
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   2|37.94|21.92|52.09|     230|  12.65858|14.5672406924|   0.0|  1012.6| 10.0|2013-01-01 07:30:00|
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# only showing top 3 rows
#
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |faa|               name|    lat|       lon|alt| tz|dst|origin|year|month|day|hour| temp| dewp|humid|wind_dir|wind_speed|    wind_gust|precip|pressure|visib|          time_hour|
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   0|37.04|21.92|53.97|     230|  10.35702|11.9186514756|   0.0|  1013.9| 10.0|2013-01-01 05:30:00|
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   1|37.04|21.92|53.97|     230|  13.80936|15.8915353008|   0.0|    1013| 10.0|2013-01-01 06:30:00|
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   2|37.94|21.92|52.09|     230|  12.65858|14.5672406924|   0.0|  1012.6| 10.0|2013-01-01 07:30:00|
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# only showing top 3 rows
#
# +---+--------------------+----------+-----------+----+---+---+------+----+-----+----+----+----+----+-----+--------+----------+---------+------+--------+-----+---------+
# |faa|                name|       lat|        lon| alt| tz|dst|origin|year|month| day|hour|temp|dewp|humid|wind_dir|wind_speed|wind_gust|precip|pressure|visib|time_hour|
# +---+--------------------+----------+-----------+----+---+---+------+----+-----+----+----+----+----+-----+--------+----------+---------+------+--------+-----+---------+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|  null|null| null|null|null|null|null| null|    null|      null|     null|  null|    null| null|     null|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|  null|null| null|null|null|null|null| null|    null|      null|     null|  null|    null| null|     null|
# |06C| Schaumburg Regional|41.9893408|-88.1012428| 801| -6|  A|  null|null| null|null|null|null|null| null|    null|      null|     null|  null|    null| null|     null|
# +---+--------------------+----------+-----------+----+---+---+------+----+-----+----+----+----+----+-----+--------+----------+---------+------+--------+-----+---------+
# only showing top 3 rows

# %% [markdown]
# ### SQL queries against DataFrame

# %%
# 11. Many of the operations can be accessed by writing SQL queries in spark.sql().
# To make an existing Spark dataframe usable for spark.sql(), one needs to
#   register said dataframe as a temporary table.

# 11.1 As an example, we can register the two dataframes as temp tables then
#      join them through spark.sql().

airports_df.createOrReplaceTempView('dfa_temp')
weather_df.createOrReplaceTempView('dfw_temp')

# %%
# 11.2 Simple SQL query. SQLContext is no longer needed. 'spark'
#            session object can be used.

dfj = spark.sql('select * from dfa_temp' )
dfj.show(3)
# Out:
# +---+--------------------+----------+-----------+----+---+---+
# |faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# |04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
# |06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
# |06C| Schaumburg Regional|41.9893408|-88.1012428| 801| -6|  A|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 3 rows

# %%
# 11.3 Now the SQL join

dfj = spark.sql('select * from dfa_temp a, dfw_temp b where a.faa = b.origin' )
dfj.show(3)
# Out:
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |faa|               name|    lat|       lon|alt| tz|dst|origin|year|month|day|hour| temp| dewp|humid|wind_dir|wind_speed|    wind_gust|precip|pressure|visib|          time_hour|
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   0|37.04|21.92|53.97|     230|  10.35702|11.9186514756|   0.0|  1013.9| 10.0|2013-01-01 05:30:00|
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   1|37.04|21.92|53.97|     230|  13.80936|15.8915353008|   0.0|    1013| 10.0|2013-01-01 06:30:00|
# |EWR|Newark Liberty Intl|40.6925|-74.168667| 18| -5|  A|   EWR|2013|    1|  1|   2|37.94|21.92|52.09|     230|  12.65858|14.5672406924|   0.0|  1012.6| 10.0|2013-01-01 07:30:00|
# +---+-------------------+-------+----------+---+---+---+------+----+-----+---+----+-----+-----+-----+--------+----------+-------------+------+--------+-----+-------------------+
# only showing top 3 rows

# %%
# 12. Drop a columns

airports_df.drop('name').show(3)

# 12.1  Or drop multiple columns

columns_to_drop = ['name', 'lat']
xx =airports_df.drop(*columns_to_drop)
xx.show(3)
# Out:
# +---+----------+-----------+----+---+---+
# |faa|       lat|        lon| alt| tz|dst|
# +---+----------+-----------+----+---+---+
# |04G|41.1304722|-80.6195833|1044| -5|  A|
# |06A|32.4605722|-85.6800278| 264| -5|  A|
# |06C|41.9893408|-88.1012428| 801| -6|  A|
# +---+----------+-----------+----+---+---+
# only showing top 3 rows
#
# +---+-----------+----+---+---+
# |faa|        lon| alt| tz|dst|
# +---+-----------+----+---+---+
# |04G|-80.6195833|1044| -5|  A|
# |06A|-85.6800278| 264| -5|  A|
# |06C|-88.1012428| 801| -6|  A|
# +---+-----------+----+---+---+
# only showing top 3 rows

# %%
########### I am done ####################
